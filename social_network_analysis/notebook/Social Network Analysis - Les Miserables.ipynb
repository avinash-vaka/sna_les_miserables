# %% [markdown]
# # Social Network Analysis of the French novel Les Miserables (Victor Hugo)
#
#
# A summary of the novel can be found at https://www.sparknotes.com/lit/lesmis/summary/
#
#
# - lesmis.gml - contains the weighted network of coappearances of characters
# - Each node in this network is labeled by one character
# - We define coapperance as being seen in the same chapter of the novel
# - An edge between two nodes represents that those two characters will appear in the same chapter
# - The value of the eges represents the number of such coapperances
# - The data is sourced from D.E. Knuth, The Stanford GraphBase (https://www-cs-faculty.stanford.edu/~knuth/sgb.html)

# %%
# Importing networkx
import matplotlib.pyplot as plt
import networkx as nx
# Check the version
nx.__version__
# Out:
# '2.8.4'

# %%
# Load the graph
fil = nx.read_gml('../data/lesmis.gml')
fil
print(fil.order())
print(fil.size())
# Out:
# 77
# 254

# %% [markdown]
# ### Visualizing with networkx layouts

# %%
G = nx.florentine_families_graph()
nodes,edges = G.order(), G.size()
print ("No. of Nodes: ", nodes)
print ("No. of Edges: ", edges)


#If there are isolates, many of the algorithms will fail. You have to remove those")
print("Isolates = ",list(nx.isolates(G)))
# Out:
# No. of Nodes:  15
# No. of Edges:  20
# Isolates =  []

# %%
# Newman_watts_strogatz graph
neighbours=5
G = nx.newman_watts_strogatz_graph(nodes,neighbours,0.1)
fig = plt.figure(figsize =(5 ,5))
nx.draw(G, with_labels = False, node_size = 20, linewidths = 0.5, width = 0.5)
plt.show()

# %%
# Barabasi graph
G = nx.barabasi_albert_graph(nodes,neighbours)

fig = plt.figure(figsize =(5 ,5))
nx.draw(G, with_labels = False, node_size = 20, linewidths = 0.5, width = 0.5)
plt.show()

# %%
# Normal networkx graph
# %matplotlib inline
fig = plt.figure(figsize =(10,10))
nx.draw_networkx(fil)
plt.show()

# %%
# Overall Graph
nx.draw(fil)
plt.show()

# %%
# Precompute the layout and then plot
pos_spring = nx.spring_layout(fil)
pos_fr = nx.fruchterman_reingold_layout(fil)
pos_fr
nx.draw(fil, pos=pos_fr)
plt.show()

# %% [markdown]
# ### Let's list the nodes and edges with their attributes

# %%
# Print the nodes:
print("The nodes in the graph are: ")
list(fil.nodes())
# Out:
# The nodes in the graph are:
# ['Myriel',
#  'Napoleon',
#  'MlleBaptistine',
#  'MmeMagloire',
#  'CountessDeLo',
#  'Geborand',
#  'Champtercier',
#  'Cravatte',
#  'Count',
#  'OldMan',
#  'Labarre',
#  'Valjean',
#  'Marguerite',
#  'MmeDeR',
#  'Isabeau',
#  'Gervais',
#  'Tholomyes',
#  'Listolier',
#  'Fameuil',
#  'Blacheville',
#  'Favourite',
#  'Dahlia',
#  'Zephine',
#  'Fantine',
#  'MmeThenardier',
#  'Thenardier',
#  'Cosette',
#  'Javert',
#  'Fauchelevent',
#  'Bamatabois',
#  'Perpetue',
#  'Simplice',
#  'Scaufflaire',
#  'Woman1',
#  'Judge',
#  'Champmathieu',
#  'Brevet',
#  'Chenildieu',
#  'Cochepaille',
#  'Pontmercy',
#  'Boulatruelle',
#  'Eponine',
#  'Anzelma',
#  'Woman2',
#  'MotherInnocent',
#  'Gribier',
#  'Jondrette',
#  'MmeBurgon',
#  'Gavroche',
#  'Gillenormand',
#  'Magnon',
#  'MlleGillenormand',
#  'MmePontmercy',
#  'MlleVaubois',
#  'LtGillenormand',
#  'Marius',
#  'BaronessT',
#  'Mabeuf',
#  'Enjolras',
#  'Combeferre',
#  'Prouvaire',
#  'Feuilly',
#  'Courfeyrac',
#  'Bahorel',
#  'Bossuet',
#  'Joly',
#  'Grantaire',
#  'MotherPlutarch',
#  'Gueulemer',
#  'Babet',
#  'Claquesous',
#  'Montparnasse',
#  'Toussaint',
#  'Child1',
#  'Child2',
#  'Brujon',
#  'MmeHucheloup']

# %%
# print the edges:
print("The edges in the graph with their attributes are: ")
nx.get_edge_attributes(fil,'value')
# Out:
# The edges in the graph with their attributes are:
# {('Myriel', 'Napoleon'): 1,
#  ('Myriel', 'MlleBaptistine'): 8,
#  ('Myriel', 'MmeMagloire'): 10,
#  ('Myriel', 'CountessDeLo'): 1,
#  ('Myriel', 'Geborand'): 1,
#  ('Myriel', 'Champtercier'): 1,
#  ('Myriel', 'Cravatte'): 1,
#  ('Myriel', 'Count'): 2,
#  ('Myriel', 'OldMan'): 1,
#  ('Myriel', 'Valjean'): 5,
#  ('MlleBaptistine', 'MmeMagloire'): 6,
#  ('MlleBaptistine', 'Valjean'): 3,
#  ('MmeMagloire', 'Valjean'): 3,
#  ('Labarre', 'Valjean'): 1,
#  ('Valjean', 'Marguerite'): 1,
#  ('Valjean', 'MmeDeR'): 1,
#  ('Valjean', 'Isabeau'): 1,
#  ('Valjean', 'Gervais'): 1,
#  ('Valjean', 'Fantine'): 9,
#  ('Valjean', 'MmeThenardier'): 7,
#  ('Valjean', 'Thenardier'): 12,
#  ('Valjean', 'Cosette'): 31,
#  ('Valjean', 'Javert'): 17,
#  ('Valjean', 'Fauchelevent'): 8,
#  ('Valjean', 'Bamatabois'): 2,
#  ('Valjean', 'Simplice'): 3,
#  ('Valjean', 'Scaufflaire'): 1,
#  ('Valjean', 'Woman1'): 2,
#  ('Valjean', 'Judge'): 3,
#  ('Valjean', 'Champmathieu'): 3,
#  ('Valjean', 'Brevet'): 2,
#  ('Valjean', 'Chenildieu'): 2,
#  ('Valjean', 'Cochepaille'): 2,
#  ('Valjean', 'Woman2'): 3,
#  ('Valjean', 'MotherInnocent'): 1,
#  ('Valjean', 'Gavroche'): 1,
#  ('Valjean', 'Gillenormand'): 2,
#  ('Valjean', 'MlleGillenormand'): 2,
#  ('Valjean', 'Marius'): 19,
#  ('Valjean', 'Enjolras'): 4,
#  ('Valjean', 'Bossuet'): 1,
#  ('Valjean', 'Gueulemer'): 1,
#  ('Valjean', 'Babet'): 1,
#  ('Valjean', 'Claquesous'): 1,
#  ('Valjean', 'Montparnasse'): 1,
#  ('Valjean', 'Toussaint'): 1,
#  ('Marguerite', 'Fantine'): 2,
#  ('Tholomyes', 'Listolier'): 4,
#  ('Tholomyes', 'Fameuil'): 4,
#  ('Tholomyes', 'Blacheville'): 4,
#  ('Tholomyes', 'Favourite'): 3,
#  ('Tholomyes', 'Dahlia'): 3,
#  ('Tholomyes', 'Zephine'): 3,
#  ('Tholomyes', 'Fantine'): 3,
#  ('Tholomyes', 'Cosette'): 1,
#  ('Tholomyes', 'Marius'): 1,
#  ('Listolier', 'Fameuil'): 4,
#  ('Listolier', 'Blacheville'): 4,
#  ('Listolier', 'Favourite'): 3,
#  ('Listolier', 'Dahlia'): 3,
#  ('Listolier', 'Zephine'): 3,
#  ('Listolier', 'Fantine'): 3,
#  ('Fameuil', 'Blacheville'): 4,
#  ('Fameuil', 'Favourite'): 3,
#  ('Fameuil', 'Dahlia'): 3,
#  ('Fameuil', 'Zephine'): 3,
#  ('Fameuil', 'Fantine'): 3,
#  ('Blacheville', 'Favourite'): 4,
#  ('Blacheville', 'Dahlia'): 3,
#  ('Blacheville', 'Zephine'): 3,
#  ('Blacheville', 'Fantine'): 3,
#  ('Favourite', 'Dahlia'): 5,
#  ('Favourite', 'Zephine'): 4,
#  ('Favourite', 'Fantine'): 4,
#  ('Dahlia', 'Zephine'): 4,
#  ('Dahlia', 'Fantine'): 4,
#  ('Zephine', 'Fantine'): 4,
#  ('Fantine', 'MmeThenardier'): 2,
#  ('Fantine', 'Thenardier'): 1,
#  ('Fantine', 'Javert'): 5,
#  ('Fantine', 'Bamatabois'): 1,
#  ('Fantine', 'Perpetue'): 1,
#  ('Fantine', 'Simplice'): 2,
#  ('MmeThenardier', 'Thenardier'): 13,
#  ('MmeThenardier', 'Cosette'): 4,
#  ('MmeThenardier', 'Javert'): 1,
#  ('MmeThenardier', 'Eponine'): 2,
#  ('MmeThenardier', 'Anzelma'): 1,
#  ('MmeThenardier', 'Magnon'): 1,
#  ('MmeThenardier', 'Gueulemer'): 1,
#  ('MmeThenardier', 'Babet'): 1,
#  ('MmeThenardier', 'Claquesous'): 1,
#  ('Thenardier', 'Cosette'): 1,
#  ('Thenardier', 'Javert'): 5,
#  ('Thenardier', 'Pontmercy'): 1,
#  ('Thenardier', 'Boulatruelle'): 1,
#  ('Thenardier', 'Eponine'): 3,
#  ('Thenardier', 'Anzelma'): 2,
#  ('Thenardier', 'Gavroche'): 1,
#  ('Thenardier', 'Marius'): 2,
#  ('Thenardier', 'Gueulemer'): 5,
#  ('Thenardier', 'Babet'): 6,
#  ('Thenardier', 'Claquesous'): 4,
#  ('Thenardier', 'Montparnasse'): 1,
#  ('Thenardier', 'Brujon'): 3,
#  ('Cosette', 'Javert'): 1,
#  ('Cosette', 'Woman2'): 1,
#  ('Cosette', 'Gillenormand'): 3,
#  ('Cosette', 'MlleGillenormand'): 2,
#  ('Cosette', 'LtGillenormand'): 1,
#  ('Cosette', 'Marius'): 21,
#  ('Cosette', 'Toussaint'): 2,
#  ('Javert', 'Fauchelevent'): 1,
#  ('Javert', 'Bamatabois'): 1,
#  ('Javert', 'Simplice'): 1,
#  ('Javert', 'Woman1'): 1,
#  ('Javert', 'Woman2'): 1,
#  ('Javert', 'Gavroche'): 1,
#  ('Javert', 'Enjolras'): 6,
#  ('Javert', 'Gueulemer'): 1,
#  ('Javert', 'Babet'): 2,
#  ('Javert', 'Claquesous'): 1,
#  ('Javert', 'Montparnasse'): 1,
#  ('Javert', 'Toussaint'): 1,
#  ('Fauchelevent', 'MotherInnocent'): 3,
#  ('Fauchelevent', 'Gribier'): 2,
#  ('Bamatabois', 'Judge'): 2,
#  ('Bamatabois', 'Champmathieu'): 2,
#  ('Bamatabois', 'Brevet'): 1,
#  ('Bamatabois', 'Chenildieu'): 1,
#  ('Bamatabois', 'Cochepaille'): 1,
#  ('Perpetue', 'Simplice'): 2,
#  ('Judge', 'Champmathieu'): 3,
#  ('Judge', 'Brevet'): 2,
#  ('Judge', 'Chenildieu'): 2,
#  ('Judge', 'Cochepaille'): 2,
#  ('Champmathieu', 'Brevet'): 2,
#  ('Champmathieu', 'Chenildieu'): 2,
#  ('Champmathieu', 'Cochepaille'): 2,
#  ('Brevet', 'Chenildieu'): 2,
#  ('Brevet', 'Cochepaille'): 2,
#  ('Chenildieu', 'Cochepaille'): 2,
#  ('Pontmercy', 'MmePontmercy'): 1,
#  ('Pontmercy', 'Marius'): 1,
#  ('Eponine', 'Anzelma'): 2,
#  ('Eponine', 'Marius'): 5,
#  ('Eponine', 'Mabeuf'): 1,
#  ('Eponine', 'Courfeyrac'): 1,
#  ('Eponine', 'Gueulemer'): 1,
#  ('Eponine', 'Babet'): 1,
#  ('Eponine', 'Claquesous'): 1,
#  ('Eponine', 'Montparnasse'): 1,
#  ('Eponine', 'Brujon'): 1,
#  ('Jondrette', 'MmeBurgon'): 1,
#  ('MmeBurgon', 'Gavroche'): 2,
#  ('Gavroche', 'Marius'): 4,
#  ('Gavroche', 'Mabeuf'): 1,
#  ('Gavroche', 'Enjolras'): 7,
#  ('Gavroche', 'Combeferre'): 6,
#  ('Gavroche', 'Prouvaire'): 1,
#  ('Gavroche', 'Feuilly'): 2,
#  ('Gavroche', 'Courfeyrac'): 7,
#  ('Gavroche', 'Bahorel'): 5,
#  ('Gavroche', 'Bossuet'): 5,
#  ('Gavroche', 'Joly'): 3,
#  ('Gavroche', 'Grantaire'): 1,
#  ('Gavroche', 'Gueulemer'): 1,
#  ('Gavroche', 'Babet'): 1,
#  ('Gavroche', 'Montparnasse'): 1,
#  ('Gavroche', 'Child1'): 2,
#  ('Gavroche', 'Child2'): 2,
#  ('Gavroche', 'Brujon'): 1,
#  ('Gavroche', 'MmeHucheloup'): 1,
#  ('Gillenormand', 'Magnon'): 1,
#  ('Gillenormand', 'MlleGillenormand'): 9,
#  ('Gillenormand', 'LtGillenormand'): 1,
#  ('Gillenormand', 'Marius'): 12,
#  ('Gillenormand', 'BaronessT'): 1,
#  ('MlleGillenormand', 'MmePontmercy'): 1,
#  ('MlleGillenormand', 'MlleVaubois'): 1,
#  ('MlleGillenormand', 'LtGillenormand'): 2,
#  ('MlleGillenormand', 'Marius'): 6,
#  ('LtGillenormand', 'Marius'): 1,
#  ('Marius', 'BaronessT'): 1,
#  ('Marius', 'Mabeuf'): 1,
#  ('Marius', 'Enjolras'): 7,
#  ('Marius', 'Combeferre'): 5,
#  ('Marius', 'Feuilly'): 1,
#  ('Marius', 'Courfeyrac'): 9,
#  ('Marius', 'Bahorel'): 1,
#  ('Marius', 'Bossuet'): 5,
#  ('Marius', 'Joly'): 2,
#  ('Mabeuf', 'Enjolras'): 1,
#  ('Mabeuf', 'Combeferre'): 2,
#  ('Mabeuf', 'Feuilly'): 1,
#  ('Mabeuf', 'Courfeyrac'): 2,
#  ('Mabeuf', 'Bahorel'): 2,
#  ('Mabeuf', 'Bossuet'): 1,
#  ('Mabeuf', 'Joly'): 1,
#  ('Mabeuf', 'MotherPlutarch'): 3,
#  ('Enjolras', 'Combeferre'): 15,
#  ('Enjolras', 'Prouvaire'): 4,
#  ('Enjolras', 'Feuilly'): 6,
#  ('Enjolras', 'Courfeyrac'): 17,
#  ('Enjolras', 'Bahorel'): 4,
#  ('Enjolras', 'Bossuet'): 10,
#  ('Enjolras', 'Joly'): 5,
#  ('Enjolras', 'Grantaire'): 3,
#  ('Enjolras', 'Claquesous'): 1,
#  ('Enjolras', 'MmeHucheloup'): 1,
#  ('Combeferre', 'Prouvaire'): 2,
#  ('Combeferre', 'Feuilly'): 5,
#  ('Combeferre', 'Courfeyrac'): 13,
#  ('Combeferre', 'Bahorel'): 5,
#  ('Combeferre', 'Bossuet'): 9,
#  ('Combeferre', 'Joly'): 5,
#  ('Combeferre', 'Grantaire'): 1,
#  ('Prouvaire', 'Feuilly'): 2,
#  ('Prouvaire', 'Courfeyrac'): 3,
#  ('Prouvaire', 'Bahorel'): 2,
#  ('Prouvaire', 'Bossuet'): 2,
#  ('Prouvaire', 'Joly'): 2,
#  ('Prouvaire', 'Grantaire'): 1,
#  ('Feuilly', 'Courfeyrac'): 6,
#  ('Feuilly', 'Bahorel'): 3,
#  ('Feuilly', 'Bossuet'): 6,
#  ('Feuilly', 'Joly'): 5,
#  ('Feuilly', 'Grantaire'): 1,
#  ('Courfeyrac', 'Bahorel'): 6,
#  ('Courfeyrac', 'Bossuet'): 12,
#  ('Courfeyrac', 'Joly'): 5,
#  ('Courfeyrac', 'Grantaire'): 2,
#  ('Courfeyrac', 'MmeHucheloup'): 1,
#  ('Bahorel', 'Bossuet'): 4,
#  ('Bahorel', 'Joly'): 5,
#  ('Bahorel', 'Grantaire'): 1,
#  ('Bahorel', 'MmeHucheloup'): 1,
#  ('Bossuet', 'Joly'): 7,
#  ('Bossuet', 'Grantaire'): 3,
#  ('Bossuet', 'MmeHucheloup'): 1,
#  ('Joly', 'Grantaire'): 2,
#  ('Joly', 'MmeHucheloup'): 1,
#  ('Grantaire', 'MmeHucheloup'): 1,
#  ('Gueulemer', 'Babet'): 6,
#  ('Gueulemer', 'Claquesous'): 4,
#  ('Gueulemer', 'Montparnasse'): 2,
#  ('Gueulemer', 'Brujon'): 3,
#  ('Babet', 'Claquesous'): 4,
#  ('Babet', 'Montparnasse'): 2,
#  ('Babet', 'Brujon'): 3,
#  ('Claquesous', 'Montparnasse'): 2,
#  ('Claquesous', 'Brujon'): 1,
#  ('Montparnasse', 'Brujon'): 1,
#  ('Child1', 'Child2'): 3}

# %% [markdown]
# ### Centrality analysis (degree, closeness, betweenness, eigenvector) of all the nodes

# %%
# Getting the eigen vector centrality
e = nx.eigenvector_centrality(fil)

# Sorting 
import operator
sorted_x = sorted(e.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_x)
# Out:
# [('Gavroche', 0.3178389397749768), ('Valjean', 0.2676181759885394), ('Enjolras', 0.2671786328235667), ('Marius', 0.25911114534178753), ('Bossuet', 0.24213078637474136), ('Courfeyrac', 0.23246719717021408), ('Bahorel', 0.22155360926119969), ('Joly', 0.22155360926119969), ('Combeferre', 0.21073457488115618), ('Feuilly', 0.21073457488115618), ('Mabeuf', 0.19502891203664763), ('Thenardier', 0.1878077051550095), ('Grantaire', 0.18663538887401085), ('Javert', 0.18422516321025706), ('Prouvaire', 0.17581635449396735), ('Gueulemer', 0.14543155406625), ('Babet', 0.14543155406625), ('Eponine', 0.14193827361489472), ('Claquesous', 0.14153627306562794), ('MmeHucheloup', 0.14071116072806064), ('Montparnasse', 0.13602919446668407), ('MmeThenardier', 0.12228242172143367), ('Cosette', 0.11103702398134035), ('Brujon', 0.10128691502674181), ('Fantine', 0.08975922949834117), ('Gillenormand', 0.06539729702430215), ('MlleGillenormand', 0.06316905144338801), ('Bamatabois', 0.06227506194694947), ('Tholomyes', 0.0481461558640121), ('Woman2', 0.04688494243431426), ('Toussaint', 0.04688494243431426), ('Simplice', 0.04605501100583567), ('LtGillenormand', 0.0415398399560889), ('Judge', 0.04120828302958654), ('Champmathieu', 0.04120828302958654), ('Brevet', 0.04120828302958654), ('Chenildieu', 0.04120828302958654), ('Cochepaille', 0.04120828302958654), ('Fauchelevent', 0.040048606735689954), ('Pontmercy', 0.037926966720036696), ('Anzelma', 0.03765154186582525), ('Woman1', 0.037636139536560614), ('Marguerite', 0.02976771474076885), ('Child1', 0.028879259336728292), ('Child2', 0.028879259336728292), ('Myriel', 0.028134336026755368), ('BaronessT', 0.02702941386613705), ('MlleBaptistine', 0.02687299983699642), ('MmeMagloire', 0.02687299983699642), ('MmeBurgon', 0.02665876769778803), ('MotherInnocent', 0.025627007259539696), ('Labarre', 0.022291152877501868), ('MmeDeR', 0.022291152877501868), ('Isabeau', 0.022291152877501868), ('Gervais', 0.022291152877501868), ('Scaufflaire', 0.022291152877501868), ('Listolier', 0.01968573670953793), ('Fameuil', 0.01968573670953793), ('Blacheville', 0.01968573670953793), ('Favourite', 0.01968573670953793), ('Dahlia', 0.01968573670953793), ('Zephine', 0.01968573670953793), ('MotherPlutarch', 0.016244465520148774), ('Boulatruelle', 0.01564337736411263), ('Magnon', 0.01563275890749716), ('Perpetue', 0.01131273156589345), ('MmePontmercy', 0.008420710184175475), ('MlleVaubois', 0.005261623192198207), ('Gribier', 0.0033358543820378307), ('Napoleon', 0.0023434559950116177), ('CountessDeLo', 0.0023434559950116177), ('Geborand', 0.0023434559950116177), ('Champtercier', 0.0023434559950116177), ('Cravatte', 0.0023434559950116177), ('Count', 0.0023434559950116177), ('OldMan', 0.0023434559950116177), ('Jondrette', 0.002220491638940264)]

# %%
# Getting the degree centrality
e = nx.degree_centrality(fil)

# Sorting 
import operator
sorted_x = sorted(e.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_x)
# Out:
# [('Valjean', 0.47368421052631576), ('Gavroche', 0.2894736842105263), ('Marius', 0.25), ('Javert', 0.22368421052631576), ('Thenardier', 0.21052631578947367), ('Fantine', 0.19736842105263158), ('Enjolras', 0.19736842105263158), ('Courfeyrac', 0.17105263157894735), ('Bossuet', 0.17105263157894735), ('Bahorel', 0.15789473684210525), ('Joly', 0.15789473684210525), ('MmeThenardier', 0.14473684210526316), ('Cosette', 0.14473684210526316), ('Eponine', 0.14473684210526316), ('Mabeuf', 0.14473684210526316), ('Combeferre', 0.14473684210526316), ('Feuilly', 0.14473684210526316), ('Myriel', 0.13157894736842105), ('Grantaire', 0.13157894736842105), ('Gueulemer', 0.13157894736842105), ('Babet', 0.13157894736842105), ('Claquesous', 0.13157894736842105), ('Tholomyes', 0.11842105263157894), ('Prouvaire', 0.11842105263157894), ('Montparnasse', 0.11842105263157894), ('Bamatabois', 0.10526315789473684), ('Listolier', 0.09210526315789473), ('Fameuil', 0.09210526315789473), ('Blacheville', 0.09210526315789473), ('Favourite', 0.09210526315789473), ('Dahlia', 0.09210526315789473), ('Zephine', 0.09210526315789473), ('Gillenormand', 0.09210526315789473), ('MlleGillenormand', 0.09210526315789473), ('Brujon', 0.09210526315789473), ('MmeHucheloup', 0.09210526315789473), ('Judge', 0.07894736842105263), ('Champmathieu', 0.07894736842105263), ('Brevet', 0.07894736842105263), ('Chenildieu', 0.07894736842105263), ('Cochepaille', 0.07894736842105263), ('Fauchelevent', 0.05263157894736842), ('Simplice', 0.05263157894736842), ('LtGillenormand', 0.05263157894736842), ('MlleBaptistine', 0.039473684210526314), ('MmeMagloire', 0.039473684210526314), ('Pontmercy', 0.039473684210526314), ('Anzelma', 0.039473684210526314), ('Woman2', 0.039473684210526314), ('Toussaint', 0.039473684210526314), ('Marguerite', 0.02631578947368421), ('Perpetue', 0.02631578947368421), ('Woman1', 0.02631578947368421), ('MotherInnocent', 0.02631578947368421), ('MmeBurgon', 0.02631578947368421), ('Magnon', 0.02631578947368421), ('MmePontmercy', 0.02631578947368421), ('BaronessT', 0.02631578947368421), ('Child1', 0.02631578947368421), ('Child2', 0.02631578947368421), ('Napoleon', 0.013157894736842105), ('CountessDeLo', 0.013157894736842105), ('Geborand', 0.013157894736842105), ('Champtercier', 0.013157894736842105), ('Cravatte', 0.013157894736842105), ('Count', 0.013157894736842105), ('OldMan', 0.013157894736842105), ('Labarre', 0.013157894736842105), ('MmeDeR', 0.013157894736842105), ('Isabeau', 0.013157894736842105), ('Gervais', 0.013157894736842105), ('Scaufflaire', 0.013157894736842105), ('Boulatruelle', 0.013157894736842105), ('Gribier', 0.013157894736842105), ('Jondrette', 0.013157894736842105), ('MlleVaubois', 0.013157894736842105), ('MotherPlutarch', 0.013157894736842105)]

# %%
# Getting the closeness centrality
e = nx.closeness_centrality(fil)

# Sorting 
import operator
sorted_x = sorted(e.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_x)
# Out:
# [('Valjean', 0.6440677966101694), ('Marius', 0.5314685314685315), ('Thenardier', 0.5170068027210885), ('Javert', 0.5170068027210885), ('Gavroche', 0.5135135135135135), ('Enjolras', 0.4810126582278481), ('Cosette', 0.4779874213836478), ('Bossuet', 0.475), ('Gueulemer', 0.4634146341463415), ('Babet', 0.4634146341463415), ('Fantine', 0.46060606060606063), ('MmeThenardier', 0.46060606060606063), ('Montparnasse', 0.4578313253012048), ('Claquesous', 0.4523809523809524), ('Gillenormand', 0.4418604651162791), ('MlleGillenormand', 0.4418604651162791), ('Myriel', 0.4293785310734463), ('Bamatabois', 0.42696629213483145), ('Simplice', 0.4175824175824176), ('MlleBaptistine', 0.41304347826086957), ('MmeMagloire', 0.41304347826086957), ('Marguerite', 0.41304347826086957), ('Judge', 0.40425531914893614), ('Champmathieu', 0.40425531914893614), ('Brevet', 0.40425531914893614), ('Chenildieu', 0.40425531914893614), ('Cochepaille', 0.40425531914893614), ('Fauchelevent', 0.4021164021164021), ('Woman2', 0.4021164021164021), ('Toussaint', 0.4021164021164021), ('Courfeyrac', 0.4), ('MotherInnocent', 0.39790575916230364), ('Woman1', 0.3958333333333333), ('Eponine', 0.3958333333333333), ('Mabeuf', 0.3958333333333333), ('Labarre', 0.39378238341968913), ('MmeDeR', 0.39378238341968913), ('Isabeau', 0.39378238341968913), ('Gervais', 0.39378238341968913), ('Scaufflaire', 0.39378238341968913), ('Bahorel', 0.39378238341968913), ('Joly', 0.39378238341968913), ('Tholomyes', 0.3917525773195876), ('Combeferre', 0.3917525773195876), ('Feuilly', 0.3917525773195876), ('Brujon', 0.38), ('Pontmercy', 0.37254901960784315), ('LtGillenormand', 0.36538461538461536), ('Grantaire', 0.3584905660377358), ('Prouvaire', 0.3568075117370892), ('MmeHucheloup', 0.35348837209302325), ('Anzelma', 0.35185185185185186), ('BaronessT', 0.35185185185185186), ('MmeBurgon', 0.3438914027149321), ('Boulatruelle', 0.34234234234234234), ('Child1', 0.34234234234234234), ('Child2', 0.34234234234234234), ('Listolier', 0.34080717488789236), ('Fameuil', 0.34080717488789236), ('Blacheville', 0.34080717488789236), ('Favourite', 0.34080717488789236), ('Dahlia', 0.34080717488789236), ('Zephine', 0.34080717488789236), ('Magnon', 0.33480176211453744), ('Perpetue', 0.3179916317991632), ('MmePontmercy', 0.3153526970954357), ('MlleVaubois', 0.3076923076923077), ('Napoleon', 0.30158730158730157), ('CountessDeLo', 0.30158730158730157), ('Geborand', 0.30158730158730157), ('Champtercier', 0.30158730158730157), ('Cravatte', 0.30158730158730157), ('Count', 0.30158730158730157), ('OldMan', 0.30158730158730157), ('Gribier', 0.2878787878787879), ('MotherPlutarch', 0.2846441947565543), ('Jondrette', 0.25675675675675674)]

# %%
# Getting the betweenness centrality
e = nx.betweenness_centrality(fil)

# Sorting 
import operator
sorted_x = sorted(e.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_x)
# Out:
# [('Valjean', 0.5699890527836184), ('Myriel', 0.17684210526315788), ('Gavroche', 0.16511250242584766), ('Marius', 0.132032488621946), ('Fantine', 0.12964454098819422), ('Thenardier', 0.07490122123424225), ('Javert', 0.05433155966478436), ('MlleGillenormand', 0.047598927875243675), ('Enjolras', 0.0425533568221771), ('Tholomyes', 0.04062934817733579), ('Bossuet', 0.03075365017995782), ('MmeThenardier', 0.02900241873046176), ('Mabeuf', 0.027661236424394314), ('Fauchelevent', 0.026491228070175437), ('MmeBurgon', 0.02631578947368421), ('Cosette', 0.023796253454148188), ('Gillenormand', 0.02021062158319776), ('Eponine', 0.011487550654163002), ('Simplice', 0.008640295033483888), ('Bamatabois', 0.008040935672514621), ('Pontmercy', 0.006925438596491228), ('Courfeyrac', 0.00526702988198833), ('Gueulemer', 0.004960383978389518), ('Babet', 0.004960383978389518), ('Claquesous', 0.00486180419559921), ('Montparnasse', 0.0038738298738298727), ('Bahorel', 0.0021854883087570067), ('Joly', 0.0021854883087570067), ('Combeferre', 0.0012501455659350393), ('Feuilly', 0.0012501455659350393), ('Brujon', 0.00043859649122807013), ('MmePontmercy', 0.0003508771929824561), ('Magnon', 0.00021720969089390142), ('Grantaire', 0.00015037593984962405), ('Napoleon', 0.0), ('MlleBaptistine', 0.0), ('MmeMagloire', 0.0), ('CountessDeLo', 0.0), ('Geborand', 0.0), ('Champtercier', 0.0), ('Cravatte', 0.0), ('Count', 0.0), ('OldMan', 0.0), ('Labarre', 0.0), ('Marguerite', 0.0), ('MmeDeR', 0.0), ('Isabeau', 0.0), ('Gervais', 0.0), ('Listolier', 0.0), ('Fameuil', 0.0), ('Blacheville', 0.0), ('Favourite', 0.0), ('Dahlia', 0.0), ('Zephine', 0.0), ('Perpetue', 0.0), ('Scaufflaire', 0.0), ('Woman1', 0.0), ('Judge', 0.0), ('Champmathieu', 0.0), ('Brevet', 0.0), ('Chenildieu', 0.0), ('Cochepaille', 0.0), ('Boulatruelle', 0.0), ('Anzelma', 0.0), ('Woman2', 0.0), ('MotherInnocent', 0.0), ('Gribier', 0.0), ('Jondrette', 0.0), ('MlleVaubois', 0.0), ('LtGillenormand', 0.0), ('BaronessT', 0.0), ('Prouvaire', 0.0), ('MotherPlutarch', 0.0), ('Toussaint', 0.0), ('Child1', 0.0), ('Child2', 0.0), ('MmeHucheloup', 0.0)]

# %% [markdown]
# ### Pearson Correlation coefficient between each pair of centrality ( vectors)

# %%
# Pearson correlation coefficient for the whole graph is: 

print("Pearson correlation coefficient for the whole graph is: ",nx.degree_pearson_correlation_coefficient(fil))
# Out:
# Pearson correlation coefficient for the whole graph is:  -0.1652251344223694

# %%
# Pearson correlation coefficient for each of the edges in the graph are:
x = list(fil.edges())
for i in x:
        print(i,"------>",nx.degree_pearson_correlation_coefficient(fil , nodes = i))
# Out:
# ('Myriel', 'Napoleon') ------> -1.0
# ('Myriel', 'MlleBaptistine') ------> -1.0
# ('Myriel', 'MmeMagloire') ------> -1.0
# ('Myriel', 'CountessDeLo') ------> -1.0
# ('Myriel', 'Geborand') ------> -1.0
# ('Myriel', 'Champtercier') ------> -1.0
# ('Myriel', 'Cravatte') ------> -1.0
# ('Myriel', 'Count') ------> -1.0
# ('Myriel', 'OldMan') ------> -1.0
# ('Myriel', 'Valjean') ------> -1.0
# ('MlleBaptistine', 'MmeMagloire') ------> nan
# ('MlleBaptistine', 'Valjean') ------> -1.0
# ('MmeMagloire', 'Valjean') ------> -1.0
# ('Labarre', 'Valjean') ------> -1.0
# ('Valjean', 'Marguerite') ------> -1.0
# ('Valjean', 'MmeDeR') ------> -1.0
# ('Valjean', 'Isabeau') ------> -1.0
# ('Valjean', 'Gervais') ------> -1.0
# ('Valjean', 'Fantine') ------> -1.0
# ('Valjean', 'MmeThenardier') ------> -1.0
# ('Valjean', 'Thenardier') ------> -1.0
# ('Valjean', 'Cosette') ------> -1.0
# ('Valjean', 'Javert') ------> -1.0
# ('Valjean', 'Fauchelevent') ------> -1.0
# ('Valjean', 'Bamatabois') ------> -1.0
# ('Valjean', 'Simplice') ------> -1.0
# ('Valjean', 'Scaufflaire') ------> -1.0
# ('Valjean', 'Woman1') ------> -1.0
# ('Valjean', 'Judge') ------> -1.0
# ('Valjean', 'Champmathieu') ------> -1.0
# ('Valjean', 'Brevet') ------> -1.0
# ('Valjean', 'Chenildieu') ------> -1.0
# ('Valjean', 'Cochepaille') ------> -1.0
# ('Valjean', 'Woman2') ------> -1.0
# ('Valjean', 'MotherInnocent') ------> -1.0
# ('Valjean', 'Gavroche') ------> -1.0
# ('Valjean', 'Gillenormand') ------> -1.0
# ('Valjean', 'MlleGillenormand') ------> -1.0
# ('Valjean', 'Marius') ------> -1.0
# ('Valjean', 'Enjolras') ------> -1.0
# ('Valjean', 'Bossuet') ------> -1.0
# ('Valjean', 'Gueulemer') ------> -1.0
# ('Valjean', 'Babet') ------> -1.0
# ('Valjean', 'Claquesous') ------> -1.0
# ('Valjean', 'Montparnasse') ------> -1.0
# ('Valjean', 'Toussaint') ------> -1.0
# ('Marguerite', 'Fantine') ------> -1.0
# ('Tholomyes', 'Listolier') ------> -1.0
# ('Tholomyes', 'Fameuil') ------> -1.0
# ('Tholomyes', 'Blacheville') ------> -1.0
# ('Tholomyes', 'Favourite') ------> -1.0
# ('Tholomyes', 'Dahlia') ------> -1.0
# ('Tholomyes', 'Zephine') ------> -1.0
# ('Tholomyes', 'Fantine') ------> -1.0
# ('Tholomyes', 'Cosette') ------> -1.0
# ('Tholomyes', 'Marius') ------> -1.0
# ('Listolier', 'Fameuil') ------> nan
# ('Listolier', 'Blacheville') ------> nan
# ('Listolier', 'Favourite') ------> nan
# ('Listolier', 'Dahlia') ------> nan
# ('Listolier', 'Zephine') ------> nan
# ('Listolier', 'Fantine') ------> -1.0
# ('Fameuil', 'Blacheville') ------> nan
# ('Fameuil', 'Favourite') ------> nan
# ('Fameuil', 'Dahlia') ------> nan
# ('Fameuil', 'Zephine') ------> nan
# ('Fameuil', 'Fantine') ------> -1.0
# ('Blacheville', 'Favourite') ------> nan
# ('Blacheville', 'Dahlia') ------> nan
# ('Blacheville', 'Zephine') ------> nan
# ('Blacheville', 'Fantine') ------> -1.0
# ('Favourite', 'Dahlia') ------> nan
# ('Favourite', 'Zephine') ------> nan
# ('Favourite', 'Fantine') ------> -1.0
# ('Dahlia', 'Zephine') ------> nan
# ('Dahlia', 'Fantine') ------> -1.0
# ('Zephine', 'Fantine') ------> -1.0
# ('Fantine', 'MmeThenardier') ------> -1.0
# ('Fantine', 'Thenardier') ------> -1.0
# ('Fantine', 'Javert') ------> -1.0
# ('Fantine', 'Bamatabois') ------> -1.0
# ('Fantine', 'Perpetue') ------> -1.0
# ('Fantine', 'Simplice') ------> -1.0
# ('MmeThenardier', 'Thenardier') ------> -1.0
# ('MmeThenardier', 'Cosette') ------> nan
# ('MmeThenardier', 'Javert') ------> -1.0
# ('MmeThenardier', 'Eponine') ------> nan
# ('MmeThenardier', 'Anzelma') ------> -1.0
# ('MmeThenardier', 'Magnon') ------> -1.0
# ('MmeThenardier', 'Gueulemer') ------> -1.0
# ('MmeThenardier', 'Babet') ------> -1.0
# ('MmeThenardier', 'Claquesous') ------> -1.0
# ('Thenardier', 'Cosette') ------> -1.0
# ('Thenardier', 'Javert') ------> -1.0
# ('Thenardier', 'Pontmercy') ------> -1.0
# ('Thenardier', 'Boulatruelle') ------> -1.0
# ('Thenardier', 'Eponine') ------> -1.0
# ('Thenardier', 'Anzelma') ------> -1.0
# ('Thenardier', 'Gavroche') ------> -1.0
# ('Thenardier', 'Marius') ------> -1.0
# ('Thenardier', 'Gueulemer') ------> -1.0
# ('Thenardier', 'Babet') ------> -1.0
# ('Thenardier', 'Claquesous') ------> -1.0
# ('Thenardier', 'Montparnasse') ------> -1.0
# ('Thenardier', 'Brujon') ------> -1.0
# ('Cosette', 'Javert') ------> -1.0
# ('Cosette', 'Woman2') ------> -1.0
# ('Cosette', 'Gillenormand') ------> -1.0
# ('Cosette', 'MlleGillenormand') ------> -1.0
# ('Cosette', 'LtGillenormand') ------> -1.0
# ('Cosette', 'Marius') ------> -1.0
# ('Cosette', 'Toussaint') ------> -1.0
# ('Javert', 'Fauchelevent') ------> -1.0
# ('Javert', 'Bamatabois') ------> -1.0
# ('Javert', 'Simplice') ------> -1.0
# ('Javert', 'Woman1') ------> -1.0
# ('Javert', 'Woman2') ------> -1.0
# ('Javert', 'Gavroche') ------> -1.0
# ('Javert', 'Enjolras') ------> -1.0
# ('Javert', 'Gueulemer') ------> -1.0
# ('Javert', 'Babet') ------> -1.0
# ('Javert', 'Claquesous') ------> -1.0
# ('Javert', 'Montparnasse') ------> -1.0
# ('Javert', 'Toussaint') ------> -1.0
# ('Fauchelevent', 'MotherInnocent') ------> -1.0
# ('Fauchelevent', 'Gribier') ------> -1.0
# ('Bamatabois', 'Judge') ------> -1.0
# ('Bamatabois', 'Champmathieu') ------> -1.0
# ('Bamatabois', 'Brevet') ------> -1.0
# ('Bamatabois', 'Chenildieu') ------> -1.0
# ('Bamatabois', 'Cochepaille') ------> -1.0
# ('Perpetue', 'Simplice') ------> -1.0
# ('Judge', 'Champmathieu') ------> nan
# ('Judge', 'Brevet') ------> nan
# ('Judge', 'Chenildieu') ------> nan
# ('Judge', 'Cochepaille') ------> nan
# ('Champmathieu', 'Brevet') ------> nan
# ('Champmathieu', 'Chenildieu') ------> nan
# ('Champmathieu', 'Cochepaille') ------> nan
# ('Brevet', 'Chenildieu') ------> nan
# ('Brevet', 'Cochepaille') ------> nan
# ('Chenildieu', 'Cochepaille') ------> nan
# ('Pontmercy', 'MmePontmercy') ------> -1.0
# ('Pontmercy', 'Marius') ------> -1.0
# ('Eponine', 'Anzelma') ------> -1.0
# ('Eponine', 'Marius') ------> -1.0
# ('Eponine', 'Mabeuf') ------> nan
# ('Eponine', 'Courfeyrac') ------> -1.0
# ('Eponine', 'Gueulemer') ------> -1.0
# ('Eponine', 'Babet') ------> -1.0
# ('Eponine', 'Claquesous') ------> -1.0
# ('Eponine', 'Montparnasse') ------> -1.0
# ('Eponine', 'Brujon') ------> -1.0
# ('Jondrette', 'MmeBurgon') ------> -1.0
# ('MmeBurgon', 'Gavroche') ------> -1.0
# ('Gavroche', 'Marius') ------> -1.0
# ('Gavroche', 'Mabeuf') ------> -1.0
# ('Gavroche', 'Enjolras') ------> -1.0
# ('Gavroche', 'Combeferre') ------> -1.0
# ('Gavroche', 'Prouvaire') ------> -1.0
# ('Gavroche', 'Feuilly') ------> -1.0
# ('Gavroche', 'Courfeyrac') ------> -1.0
# ('Gavroche', 'Bahorel') ------> -1.0
# ('Gavroche', 'Bossuet') ------> -1.0
# ('Gavroche', 'Joly') ------> -1.0
# ('Gavroche', 'Grantaire') ------> -1.0
# ('Gavroche', 'Gueulemer') ------> -1.0
# ('Gavroche', 'Babet') ------> -1.0
# ('Gavroche', 'Montparnasse') ------> -1.0
# ('Gavroche', 'Child1') ------> -1.0
# ('Gavroche', 'Child2') ------> -1.0
# ('Gavroche', 'Brujon') ------> -1.0
# ('Gavroche', 'MmeHucheloup') ------> -1.0
# ('Gillenormand', 'Magnon') ------> -1.0
# ('Gillenormand', 'MlleGillenormand') ------> nan
# ('Gillenormand', 'LtGillenormand') ------> -1.0
# ('Gillenormand', 'Marius') ------> -1.0
# ('Gillenormand', 'BaronessT') ------> -1.0
# ('MlleGillenormand', 'MmePontmercy') ------> -1.0
# ('MlleGillenormand', 'MlleVaubois') ------> -1.0
# ('MlleGillenormand', 'LtGillenormand') ------> -1.0
# ('MlleGillenormand', 'Marius') ------> -1.0
# ('LtGillenormand', 'Marius') ------> -1.0
# ('Marius', 'BaronessT') ------> -1.0
# ('Marius', 'Mabeuf') ------> -1.0
# ('Marius', 'Enjolras') ------> -1.0
# ('Marius', 'Combeferre') ------> -1.0
# ('Marius', 'Feuilly') ------> -1.0
# ('Marius', 'Courfeyrac') ------> -1.0
# ('Marius', 'Bahorel') ------> -1.0
# ('Marius', 'Bossuet') ------> -1.0
# ('Marius', 'Joly') ------> -1.0
# ('Mabeuf', 'Enjolras') ------> -1.0
# ('Mabeuf', 'Combeferre') ------> nan
# ('Mabeuf', 'Feuilly') ------> nan
# ('Mabeuf', 'Courfeyrac') ------> -1.0
# ('Mabeuf', 'Bahorel') ------> -1.0
# ('Mabeuf', 'Bossuet') ------> -1.0
# ('Mabeuf', 'Joly') ------> -1.0
# ('Mabeuf', 'MotherPlutarch') ------> -1.0
# ('Enjolras', 'Combeferre') ------> -1.0
# ('Enjolras', 'Prouvaire') ------> -1.0
# ('Enjolras', 'Feuilly') ------> -1.0
# ('Enjolras', 'Courfeyrac') ------> -1.0
# ('Enjolras', 'Bahorel') ------> -1.0
# ('Enjolras', 'Bossuet') ------> -1.0
# ('Enjolras', 'Joly') ------> -1.0
# ('Enjolras', 'Grantaire') ------> -1.0
# ('Enjolras', 'Claquesous') ------> -1.0
# ('Enjolras', 'MmeHucheloup') ------> -1.0
# ('Combeferre', 'Prouvaire') ------> -1.0
# ('Combeferre', 'Feuilly') ------> nan
# ('Combeferre', 'Courfeyrac') ------> -1.0
# ('Combeferre', 'Bahorel') ------> -1.0
# ('Combeferre', 'Bossuet') ------> -1.0
# ('Combeferre', 'Joly') ------> -1.0
# ('Combeferre', 'Grantaire') ------> -1.0
# ('Prouvaire', 'Feuilly') ------> -1.0
# ('Prouvaire', 'Courfeyrac') ------> -1.0
# ('Prouvaire', 'Bahorel') ------> -1.0
# ('Prouvaire', 'Bossuet') ------> -1.0
# ('Prouvaire', 'Joly') ------> -1.0
# ('Prouvaire', 'Grantaire') ------> -1.0
# ('Feuilly', 'Courfeyrac') ------> -1.0
# ('Feuilly', 'Bahorel') ------> -1.0
# ('Feuilly', 'Bossuet') ------> -1.0
# ('Feuilly', 'Joly') ------> -1.0
# ('Feuilly', 'Grantaire') ------> -1.0
# ('Courfeyrac', 'Bahorel') ------> -1.0
# ('Courfeyrac', 'Bossuet') ------> nan
# ('Courfeyrac', 'Joly') ------> -1.0
# ('Courfeyrac', 'Grantaire') ------> -1.0
# ('Courfeyrac', 'MmeHucheloup') ------> -1.0
# ('Bahorel', 'Bossuet') ------> -1.0
# ('Bahorel', 'Joly') ------> nan
# ('Bahorel', 'Grantaire') ------> -1.0
# ('Bahorel', 'MmeHucheloup') ------> -1.0
# ('Bossuet', 'Joly') ------> -1.0
# ('Bossuet', 'Grantaire') ------> -1.0
# ('Bossuet', 'MmeHucheloup') ------> -1.0
# ('Joly', 'Grantaire') ------> -1.0
# ('Joly', 'MmeHucheloup') ------> -1.0
# ('Grantaire', 'MmeHucheloup') ------> -1.0
# ('Gueulemer', 'Babet') ------> nan
# ('Gueulemer', 'Claquesous') ------> nan
# ('Gueulemer', 'Montparnasse') ------> -1.0
# ('Gueulemer', 'Brujon') ------> -1.0
# ('Babet', 'Claquesous') ------> nan
# ('Babet', 'Montparnasse') ------> -1.0
# ('Babet', 'Brujon') ------> -1.0
# ('Claquesous', 'Montparnasse') ------> -1.0
# ('Claquesous', 'Brujon') ------> -1.0
# ('Montparnasse', 'Brujon') ------> -1.0
# ('Child1', 'Child2') ------> nan
# /Users/avinashvaka/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
G = fil
cc=nx.closeness_centrality(G)
dc=nx.degree_centrality(G)
bc = nx.betweenness_centrality(G)
ec = nx.eigenvector_centrality(G,max_iter=1000)
sorted_dc=sorted(dc.items())
sorted_bc=sorted(bc.items())
sorted_cc=sorted(cc.items())
sorted_ec=sorted(ec.items())
#extract the centralities
deg_data=[y for x,y in sorted_dc]
close_data=[y for x,y in sorted_cc]
betw_data=[y for x,y in sorted_bc]
eig_data=[y for x,y in sorted_ec]

from scipy.stats.stats import pearsonr
r1=pearsonr(deg_data,betw_data)
s= "\n Pearson Correlation Coefficient between degree central and betweenness: " + repr(r1)
print (s)
r2=pearsonr(deg_data,close_data)
s= "\n Pearson Correlation Coefficient between degree central and closeness: " + repr(r2)
print (s)
r3=pearsonr(betw_data,close_data)
s= "\n Pearson Correlation Coefficient between betweennness and closeness: " + repr(r3)
print (s)
r4=pearsonr(betw_data,eig_data)
s= "\n Pearson Correlation Coefficient between betweennness and eigenvector : " + repr(r4)
print (s)
# Out:
#  Pearson Correlation Coefficient between degree central and betweenness: (0.7468277390180281, 6.278534881336606e-15)
#
#  Pearson Correlation Coefficient between degree central and closeness: (0.7996961811507092, 2.755674991475948e-18)
#
#  Pearson Correlation Coefficient between betweennness and closeness: (0.6287339146009842, 9.200824713262712e-10)
#
#  Pearson Correlation Coefficient between betweennness and eigenvector : (0.42310812144122967, 0.00012620658358078856)

# %% [markdown]
# ### Degree distribution histogram and a log-log plot

# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx

G = fil

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Distribution Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)

# draw graph in inset
plt.axes([1, 1, 1.2, 1.2])
Gcc = sorted((G.subgraph(c) for c in nx.connected_components(G)), key=len, reverse=True)[0]
pos = nx.spring_layout(G)
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=20)
nx.draw_networkx_edges(G, pos, alpha=0.4)

plt.show()

# %%
import collections
import matplotlib.pyplot as plt
import networkx as nx

G = fil

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
# degreeCount = collections.Counter(degree_sequence)
# deg, cnt = zip(*degreeCount.items())

# fig, ax = plt.subplots()
# plt.bar(deg, cnt, width=0.80, color='b')
plt.loglog(degree_sequence,'b-',marker='o')
plt.title("log-log plot")
plt.ylabel("Degree")
plt.xlabel("rank")
ax.set_xticks([d + 0.4 for d in deg])
ax.set_xticklabels(deg)

# draw graph in inset
plt.axes([1, 1, 1.2, 1.2])
Gcc = sorted((G.subgraph(c) for c in nx.connected_components(G)), key=len, reverse=True)[0]
pos = nx.spring_layout(G)
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=20)
nx.draw_networkx_edges(G, pos, alpha=0.4)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = fil

degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence#print "Degree sequence", degree_sequence
dmax=max(degree_sequence)

plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")

# draw graph in inset
plt.axes([0.45,0.45,0.45,0.45])
Gcc=sorted((G.subgraph(c) for c in nx.connected_components(G)), key = len, reverse=True)[0]
pos=nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc,pos,node_size=20)
nx.draw_networkx_edges(Gcc,pos,alpha=0.4)

plt.savefig("degree_histogram.png")
plt.show()

# %% [markdown]
# ### Degree assortativity for the nodes

# %%
# degree assortativity of the nodes:

print("The degree assortativity for the whole graph is: ", nx.degree_assortativity_coefficient(fil))

print("The degree assortativity for each pair of nodes is: ")
x = list(fil.edges())
for i in x:
        print(i,"------>",nx.degree_assortativity_coefficient(fil , nodes = i))
# Out:
# The degree assortativity for the whole graph is:  -0.16522513442237025
# The degree assortativity for each pair of nodes is:
# ('Myriel', 'Napoleon') ------> -1.0
# ('Myriel', 'MlleBaptistine') ------> -1.0
# ('Myriel', 'MmeMagloire') ------> -1.0
# ('Myriel', 'CountessDeLo') ------> -1.0
# ('Myriel', 'Geborand') ------> -1.0
# ('Myriel', 'Champtercier') ------> -1.0
# ('Myriel', 'Cravatte') ------> -1.0
# ('Myriel', 'Count') ------> -1.0
# ('Myriel', 'OldMan') ------> -1.0
# ('Myriel', 'Valjean') ------> -1.0
# ('MlleBaptistine', 'MmeMagloire') ------> nan
# ('MlleBaptistine', 'Valjean') ------> -1.0
# ('MmeMagloire', 'Valjean') ------> -1.0
# ('Labarre', 'Valjean') ------> -1.0
# ('Valjean', 'Marguerite') ------> -1.0
# ('Valjean', 'MmeDeR') ------> -1.0
# ('Valjean', 'Isabeau') ------> -1.0
# ('Valjean', 'Gervais') ------> -1.0
# ('Valjean', 'Fantine') ------> -1.0
# ('Valjean', 'MmeThenardier') ------> -1.0
# ('Valjean', 'Thenardier') ------> -1.0
# ('Valjean', 'Cosette') ------> -1.0
# ('Valjean', 'Javert') ------> -1.0
# ('Valjean', 'Fauchelevent') ------> -1.0
# ('Valjean', 'Bamatabois') ------> -1.0
# ('Valjean', 'Simplice') ------> -1.0
# ('Valjean', 'Scaufflaire') ------> -1.0
# ('Valjean', 'Woman1') ------> -1.0
# ('Valjean', 'Judge') ------> -1.0
# ('Valjean', 'Champmathieu') ------> -1.0
# ('Valjean', 'Brevet') ------> -1.0
# ('Valjean', 'Chenildieu') ------> -1.0
# ('Valjean', 'Cochepaille') ------> -1.0
# ('Valjean', 'Woman2') ------> -1.0
# ('Valjean', 'MotherInnocent') ------> -1.0
# ('Valjean', 'Gavroche') ------> -1.0
# ('Valjean', 'Gillenormand') ------> -1.0
# ('Valjean', 'MlleGillenormand') ------> -1.0
# ('Valjean', 'Marius') ------> -1.0
# ('Valjean', 'Enjolras') ------> -1.0
# ('Valjean', 'Bossuet') ------> -1.0
# ('Valjean', 'Gueulemer') ------> -1.0
# ('Valjean', 'Babet') ------> -1.0
# ('Valjean', 'Claquesous') ------> -1.0
# ('Valjean', 'Montparnasse') ------> -1.0
# ('Valjean', 'Toussaint') ------> -1.0
# ('Marguerite', 'Fantine') ------> -1.0
# ('Tholomyes', 'Listolier') ------> -1.0
# ('Tholomyes', 'Fameuil') ------> -1.0
# ('Tholomyes', 'Blacheville') ------> -1.0
# ('Tholomyes', 'Favourite') ------> -1.0
# ('Tholomyes', 'Dahlia') ------> -1.0
# ('Tholomyes', 'Zephine') ------> -1.0
# ('Tholomyes', 'Fantine') ------> -1.0
# ('Tholomyes', 'Cosette') ------> -1.0
# ('Tholomyes', 'Marius') ------> -1.0
# ('Listolier', 'Fameuil') ------> nan
# ('Listolier', 'Blacheville') ------> nan
# ('Listolier', 'Favourite') ------> nan
# ('Listolier', 'Dahlia') ------> nan
# ('Listolier', 'Zephine') ------> nan
# ('Listolier', 'Fantine') ------> -1.0
# ('Fameuil', 'Blacheville') ------> nan
# ('Fameuil', 'Favourite') ------> nan
# ('Fameuil', 'Dahlia') ------> nan
# ('Fameuil', 'Zephine') ------> nan
# ('Fameuil', 'Fantine') ------> -1.0
# ('Blacheville', 'Favourite') ------> nan
# ('Blacheville', 'Dahlia') ------> nan
# ('Blacheville', 'Zephine') ------> nan
# ('Blacheville', 'Fantine') ------> -1.0
# ('Favourite', 'Dahlia') ------> nan
# ('Favourite', 'Zephine') ------> nan
# ('Favourite', 'Fantine') ------> -1.0
# ('Dahlia', 'Zephine') ------> nan
# ('Dahlia', 'Fantine') ------> -1.0
# ('Zephine', 'Fantine') ------> -1.0
# ('Fantine', 'MmeThenardier') ------> -1.0
# ('Fantine', 'Thenardier') ------> -1.0
# ('Fantine', 'Javert') ------> -1.0
# ('Fantine', 'Bamatabois') ------> -1.0
# ('Fantine', 'Perpetue') ------> -1.0
# ('Fantine', 'Simplice') ------> -1.0
# ('MmeThenardier', 'Thenardier') ------> -1.0
# ('MmeThenardier', 'Cosette') ------> nan
# ('MmeThenardier', 'Javert') ------> -1.0
# ('MmeThenardier', 'Eponine') ------> nan
# ('MmeThenardier', 'Anzelma') ------> -1.0
# ('MmeThenardier', 'Magnon') ------> -1.0
# ('MmeThenardier', 'Gueulemer') ------> -1.0
# ('MmeThenardier', 'Babet') ------> -1.0
# ('MmeThenardier', 'Claquesous') ------> -1.0
# ('Thenardier', 'Cosette') ------> -1.0
# ('Thenardier', 'Javert') ------> -1.0
# ('Thenardier', 'Pontmercy') ------> -1.0
# ('Thenardier', 'Boulatruelle') ------> -1.0
# ('Thenardier', 'Eponine') ------> -1.0
# ('Thenardier', 'Anzelma') ------> -1.0
# ('Thenardier', 'Gavroche') ------> -1.0
# ('Thenardier', 'Marius') ------> -1.0
# ('Thenardier', 'Gueulemer') ------> -1.0
# ('Thenardier', 'Babet') ------> -1.0
# ('Thenardier', 'Claquesous') ------> -1.0
# ('Thenardier', 'Montparnasse') ------> -1.0
# ('Thenardier', 'Brujon') ------> -1.0
# ('Cosette', 'Javert') ------> -1.0
# ('Cosette', 'Woman2') ------> -1.0
# ('Cosette', 'Gillenormand') ------> -1.0
# ('Cosette', 'MlleGillenormand') ------> -1.0
# ('Cosette', 'LtGillenormand') ------> -1.0
# ('Cosette', 'Marius') ------> -1.0
# ('Cosette', 'Toussaint') ------> -1.0
# ('Javert', 'Fauchelevent') ------> -1.0
# ('Javert', 'Bamatabois') ------> -1.0
# ('Javert', 'Simplice') ------> -1.0
# ('Javert', 'Woman1') ------> -1.0
# ('Javert', 'Woman2') ------> -1.0
# ('Javert', 'Gavroche') ------> -1.0
# ('Javert', 'Enjolras') ------> -1.0
# ('Javert', 'Gueulemer') ------> -1.0
# ('Javert', 'Babet') ------> -1.0
# ('Javert', 'Claquesous') ------> -1.0
# ('Javert', 'Montparnasse') ------> -1.0
# ('Javert', 'Toussaint') ------> -1.0
# ('Fauchelevent', 'MotherInnocent') ------> -1.0
# ('Fauchelevent', 'Gribier') ------> -1.0
# ('Bamatabois', 'Judge') ------> -1.0
# ('Bamatabois', 'Champmathieu') ------> -1.0
# ('Bamatabois', 'Brevet') ------> -1.0
# ('Bamatabois', 'Chenildieu') ------> -1.0
# ('Bamatabois', 'Cochepaille') ------> -1.0
# ('Perpetue', 'Simplice') ------> -1.0
# ('Judge', 'Champmathieu') ------> nan
# ('Judge', 'Brevet') ------> nan
# ('Judge', 'Chenildieu') ------> nan
# ('Judge', 'Cochepaille') ------> nan
# ('Champmathieu', 'Brevet') ------> nan
# ('Champmathieu', 'Chenildieu') ------> nan
# ('Champmathieu', 'Cochepaille') ------> nan
# ('Brevet', 'Chenildieu') ------> nan
# ('Brevet', 'Cochepaille') ------> nan
# ('Chenildieu', 'Cochepaille') ------> nan
# ('Pontmercy', 'MmePontmercy') ------> -1.0
# ('Pontmercy', 'Marius') ------> -1.0
# ('Eponine', 'Anzelma') ------> -1.0
# ('Eponine', 'Marius') ------> -1.0
# ('Eponine', 'Mabeuf') ------> nan
# ('Eponine', 'Courfeyrac') ------> -1.0
# ('Eponine', 'Gueulemer') ------> -1.0
# ('Eponine', 'Babet') ------> -1.0
# ('Eponine', 'Claquesous') ------> -1.0
# ('Eponine', 'Montparnasse') ------> -1.0
# ('Eponine', 'Brujon') ------> -1.0
# ('Jondrette', 'MmeBurgon') ------> -1.0
# ('MmeBurgon', 'Gavroche') ------> -1.0
# ('Gavroche', 'Marius') ------> -1.0
# ('Gavroche', 'Mabeuf') ------> -1.0
# ('Gavroche', 'Enjolras') ------> -1.0
# ('Gavroche', 'Combeferre') ------> -1.0
# ('Gavroche', 'Prouvaire') ------> -1.0
# ('Gavroche', 'Feuilly') ------> -1.0
# ('Gavroche', 'Courfeyrac') ------> -1.0
# ('Gavroche', 'Bahorel') ------> -1.0
# ('Gavroche', 'Bossuet') ------> -1.0
# ('Gavroche', 'Joly') ------> -1.0
# ('Gavroche', 'Grantaire') ------> -1.0
# ('Gavroche', 'Gueulemer') ------> -1.0
# ('Gavroche', 'Babet') ------> -1.0
# ('Gavroche', 'Montparnasse') ------> -1.0
# ('Gavroche', 'Child1') ------> -1.0
# ('Gavroche', 'Child2') ------> -1.0
# ('Gavroche', 'Brujon') ------> -1.0
# ('Gavroche', 'MmeHucheloup') ------> -1.0
# ('Gillenormand', 'Magnon') ------> -1.0
# ('Gillenormand', 'MlleGillenormand') ------> nan
# ('Gillenormand', 'LtGillenormand') ------> -1.0
# ('Gillenormand', 'Marius') ------> -1.0
# ('Gillenormand', 'BaronessT') ------> -1.0
# ('MlleGillenormand', 'MmePontmercy') ------> -1.0
# ('MlleGillenormand', 'MlleVaubois') ------> -1.0
# ('MlleGillenormand', 'LtGillenormand') ------> -1.0
# ('MlleGillenormand', 'Marius') ------> -1.0
# ('LtGillenormand', 'Marius') ------> -1.0
# ('Marius', 'BaronessT') ------> -1.0
# ('Marius', 'Mabeuf') ------> -1.0
# ('Marius', 'Enjolras') ------> -1.0
# ('Marius', 'Combeferre') ------> -1.0
# ('Marius', 'Feuilly') ------> -1.0
# ('Marius', 'Courfeyrac') ------> -1.0
# ('Marius', 'Bahorel') ------> -1.0
# ('Marius', 'Bossuet') ------> -1.0
# ('Marius', 'Joly') ------> -1.0
# ('Mabeuf', 'Enjolras') ------> -1.0
# ('Mabeuf', 'Combeferre') ------> nan
# ('Mabeuf', 'Feuilly') ------> nan
# ('Mabeuf', 'Courfeyrac') ------> -1.0
# ('Mabeuf', 'Bahorel') ------> -1.0
# ('Mabeuf', 'Bossuet') ------> -1.0
# ('Mabeuf', 'Joly') ------> -1.0
# ('Mabeuf', 'MotherPlutarch') ------> -1.0
# ('Enjolras', 'Combeferre') ------> -1.0
# ('Enjolras', 'Prouvaire') ------> -1.0
# ('Enjolras', 'Feuilly') ------> -1.0
# ('Enjolras', 'Courfeyrac') ------> -1.0
# ('Enjolras', 'Bahorel') ------> -1.0
# ('Enjolras', 'Bossuet') ------> -1.0
# ('Enjolras', 'Joly') ------> -1.0
# ('Enjolras', 'Grantaire') ------> -1.0
# ('Enjolras', 'Claquesous') ------> -1.0
# ('Enjolras', 'MmeHucheloup') ------> -1.0
# ('Combeferre', 'Prouvaire') ------> -1.0
# ('Combeferre', 'Feuilly') ------> nan
# ('Combeferre', 'Courfeyrac') ------> -1.0
# ('Combeferre', 'Bahorel') ------> -1.0
# ('Combeferre', 'Bossuet') ------> -1.0
# ('Combeferre', 'Joly') ------> -1.0
# ('Combeferre', 'Grantaire') ------> -1.0
# ('Prouvaire', 'Feuilly') ------> -1.0
# ('Prouvaire', 'Courfeyrac') ------> -1.0
# ('Prouvaire', 'Bahorel') ------> -1.0
# ('Prouvaire', 'Bossuet') ------> -1.0
# ('Prouvaire', 'Joly') ------> -1.0
# ('Prouvaire', 'Grantaire') ------> -1.0
# ('Feuilly', 'Courfeyrac') ------> -1.0
# ('Feuilly', 'Bahorel') ------> -1.0
# ('Feuilly', 'Bossuet') ------> -1.0
# ('Feuilly', 'Joly') ------> -1.0
# ('Feuilly', 'Grantaire') ------> -1.0
# ('Courfeyrac', 'Bahorel') ------> -1.0
# ('Courfeyrac', 'Bossuet') ------> nan
# ('Courfeyrac', 'Joly') ------> -1.0
# ('Courfeyrac', 'Grantaire') ------> -1.0
# ('Courfeyrac', 'MmeHucheloup') ------> -1.0
# ('Bahorel', 'Bossuet') ------> -1.0
# ('Bahorel', 'Joly') ------> nan
# ('Bahorel', 'Grantaire') ------> -1.0
# ('Bahorel', 'MmeHucheloup') ------> -1.0
# ('Bossuet', 'Joly') ------> -1.0
# ('Bossuet', 'Grantaire') ------> -1.0
# ('Bossuet', 'MmeHucheloup') ------> -1.0
# ('Joly', 'Grantaire') ------> -1.0
# ('Joly', 'MmeHucheloup') ------> -1.0
# ('Grantaire', 'MmeHucheloup') ------> -1.0
# ('Gueulemer', 'Babet') ------> nan
# ('Gueulemer', 'Claquesous') ------> nan
# ('Gueulemer', 'Montparnasse') ------> -1.0
# ('Gueulemer', 'Brujon') ------> -1.0
# ('Babet', 'Claquesous') ------> nan
# ('Babet', 'Montparnasse') ------> -1.0
# ('Babet', 'Brujon') ------> -1.0
# ('Claquesous', 'Montparnasse') ------> -1.0
# ('Claquesous', 'Brujon') ------> -1.0
# ('Montparnasse', 'Brujon') ------> -1.0
# ('Child1', 'Child2') ------> nan
# /Users/avinashvaka/opt/anaconda3/lib/python3.9/site-packages/networkx/algorithms/assortativity/correlation.py:298: RuntimeWarning: invalid value encountered in double_scalars
#   return (xy * (M - ab)).sum() / np.sqrt(vara * varb)

# %% [markdown]
# ### Let's find the shortest paths between the pairs of nodes

# %%
# List of all nodes is 'x'
x = list(fil.nodes())

for i in range(len(x)):
    for j in range(len(x)):
        shortest = list(nx.all_shortest_paths(fil,x[i],x[j]))
        print(shortest[0], len(shortest[0]))
# Out:
# ['Myriel'] 1
# ['Myriel', 'Napoleon'] 2
# ['Myriel', 'MlleBaptistine'] 2
# ['Myriel', 'MmeMagloire'] 2
# ['Myriel', 'CountessDeLo'] 2
# ['Myriel', 'Geborand'] 2
# ['Myriel', 'Champtercier'] 2
# ['Myriel', 'Cravatte'] 2
# ['Myriel', 'Count'] 2
# ['Myriel', 'OldMan'] 2
# ['Myriel', 'Valjean', 'Labarre'] 3
# ['Myriel', 'Valjean'] 2
# ['Myriel', 'Valjean', 'Marguerite'] 3
# ['Myriel', 'Valjean', 'MmeDeR'] 3
# ['Myriel', 'Valjean', 'Isabeau'] 3
# ['Myriel', 'Valjean', 'Gervais'] 3
# ['Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Listolier'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Fameuil'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Blacheville'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Favourite'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Dahlia'] 4
# ['Myriel', 'Valjean', 'Fantine', 'Zephine'] 4
# ['Myriel', 'Valjean', 'Fantine'] 3
# ['Myriel', 'Valjean', 'MmeThenardier'] 3
# ['Myriel', 'Valjean', 'Thenardier'] 3
# ['Myriel', 'Valjean', 'Cosette'] 3
# ['Myriel', 'Valjean', 'Javert'] 3
# ['Myriel', 'Valjean', 'Fauchelevent'] 3
# ['Myriel', 'Valjean', 'Bamatabois'] 3
# ['Myriel', 'Valjean', 'Fantine', 'Perpetue'] 4
# ['Myriel', 'Valjean', 'Simplice'] 3
# ['Myriel', 'Valjean', 'Scaufflaire'] 3
# ['Myriel', 'Valjean', 'Woman1'] 3
# ['Myriel', 'Valjean', 'Judge'] 3
# ['Myriel', 'Valjean', 'Champmathieu'] 3
# ['Myriel', 'Valjean', 'Brevet'] 3
# ['Myriel', 'Valjean', 'Chenildieu'] 3
# ['Myriel', 'Valjean', 'Cochepaille'] 3
# ['Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 4
# ['Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 4
# ['Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 4
# ['Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 4
# ['Myriel', 'Valjean', 'Woman2'] 3
# ['Myriel', 'Valjean', 'MotherInnocent'] 3
# ['Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 5
# ['Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 4
# ['Myriel', 'Valjean', 'Gavroche'] 3
# ['Myriel', 'Valjean', 'Gillenormand'] 3
# ['Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 4
# ['Myriel', 'Valjean', 'MlleGillenormand'] 3
# ['Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 4
# ['Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 4
# ['Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 4
# ['Myriel', 'Valjean', 'Marius'] 3
# ['Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['Myriel', 'Valjean', 'Enjolras'] 3
# ['Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 4
# ['Myriel', 'Valjean', 'Bossuet'] 3
# ['Myriel', 'Valjean', 'Gavroche', 'Joly'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 5
# ['Myriel', 'Valjean', 'Gueulemer'] 3
# ['Myriel', 'Valjean', 'Babet'] 3
# ['Myriel', 'Valjean', 'Claquesous'] 3
# ['Myriel', 'Valjean', 'Montparnasse'] 3
# ['Myriel', 'Valjean', 'Toussaint'] 3
# ['Myriel', 'Valjean', 'Gavroche', 'Child1'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'Child2'] 4
# ['Myriel', 'Valjean', 'Thenardier', 'Brujon'] 4
# ['Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 4
# ['Napoleon', 'Myriel'] 2
# ['Napoleon'] 1
# ['Napoleon', 'Myriel', 'MlleBaptistine'] 3
# ['Napoleon', 'Myriel', 'MmeMagloire'] 3
# ['Napoleon', 'Myriel', 'CountessDeLo'] 3
# ['Napoleon', 'Myriel', 'Geborand'] 3
# ['Napoleon', 'Myriel', 'Champtercier'] 3
# ['Napoleon', 'Myriel', 'Cravatte'] 3
# ['Napoleon', 'Myriel', 'Count'] 3
# ['Napoleon', 'Myriel', 'OldMan'] 3
# ['Napoleon', 'Myriel', 'Valjean', 'Labarre'] 4
# ['Napoleon', 'Myriel', 'Valjean'] 3
# ['Napoleon', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gervais'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Cosette'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Javert'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Simplice'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Woman1'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Judge'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Brevet'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Woman2'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Marius'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['Napoleon', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Babet'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['Napoleon', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['MlleBaptistine', 'Myriel'] 2
# ['MlleBaptistine', 'Myriel', 'Napoleon'] 3
# ['MlleBaptistine'] 1
# ['MlleBaptistine', 'MmeMagloire'] 2
# ['MlleBaptistine', 'Myriel', 'CountessDeLo'] 3
# ['MlleBaptistine', 'Myriel', 'Geborand'] 3
# ['MlleBaptistine', 'Myriel', 'Champtercier'] 3
# ['MlleBaptistine', 'Myriel', 'Cravatte'] 3
# ['MlleBaptistine', 'Myriel', 'Count'] 3
# ['MlleBaptistine', 'Myriel', 'OldMan'] 3
# ['MlleBaptistine', 'Valjean', 'Labarre'] 3
# ['MlleBaptistine', 'Valjean'] 2
# ['MlleBaptistine', 'Valjean', 'Marguerite'] 3
# ['MlleBaptistine', 'Valjean', 'MmeDeR'] 3
# ['MlleBaptistine', 'Valjean', 'Isabeau'] 3
# ['MlleBaptistine', 'Valjean', 'Gervais'] 3
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Tholomyes'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Listolier'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Fameuil'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Blacheville'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Favourite'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Dahlia'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Zephine'] 4
# ['MlleBaptistine', 'Valjean', 'Fantine'] 3
# ['MlleBaptistine', 'Valjean', 'MmeThenardier'] 3
# ['MlleBaptistine', 'Valjean', 'Thenardier'] 3
# ['MlleBaptistine', 'Valjean', 'Cosette'] 3
# ['MlleBaptistine', 'Valjean', 'Javert'] 3
# ['MlleBaptistine', 'Valjean', 'Fauchelevent'] 3
# ['MlleBaptistine', 'Valjean', 'Bamatabois'] 3
# ['MlleBaptistine', 'Valjean', 'Fantine', 'Perpetue'] 4
# ['MlleBaptistine', 'Valjean', 'Simplice'] 3
# ['MlleBaptistine', 'Valjean', 'Scaufflaire'] 3
# ['MlleBaptistine', 'Valjean', 'Woman1'] 3
# ['MlleBaptistine', 'Valjean', 'Judge'] 3
# ['MlleBaptistine', 'Valjean', 'Champmathieu'] 3
# ['MlleBaptistine', 'Valjean', 'Brevet'] 3
# ['MlleBaptistine', 'Valjean', 'Chenildieu'] 3
# ['MlleBaptistine', 'Valjean', 'Cochepaille'] 3
# ['MlleBaptistine', 'Valjean', 'Thenardier', 'Pontmercy'] 4
# ['MlleBaptistine', 'Valjean', 'Thenardier', 'Boulatruelle'] 4
# ['MlleBaptistine', 'Valjean', 'MmeThenardier', 'Eponine'] 4
# ['MlleBaptistine', 'Valjean', 'MmeThenardier', 'Anzelma'] 4
# ['MlleBaptistine', 'Valjean', 'Woman2'] 3
# ['MlleBaptistine', 'Valjean', 'MotherInnocent'] 3
# ['MlleBaptistine', 'Valjean', 'Fauchelevent', 'Gribier'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 5
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'MmeBurgon'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche'] 3
# ['MlleBaptistine', 'Valjean', 'Gillenormand'] 3
# ['MlleBaptistine', 'Valjean', 'MmeThenardier', 'Magnon'] 4
# ['MlleBaptistine', 'Valjean', 'MlleGillenormand'] 3
# ['MlleBaptistine', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 4
# ['MlleBaptistine', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 4
# ['MlleBaptistine', 'Valjean', 'Cosette', 'LtGillenormand'] 4
# ['MlleBaptistine', 'Valjean', 'Marius'] 3
# ['MlleBaptistine', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['MlleBaptistine', 'Valjean', 'Enjolras'] 3
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Courfeyrac'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Bahorel'] 4
# ['MlleBaptistine', 'Valjean', 'Bossuet'] 3
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Joly'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Grantaire'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 5
# ['MlleBaptistine', 'Valjean', 'Gueulemer'] 3
# ['MlleBaptistine', 'Valjean', 'Babet'] 3
# ['MlleBaptistine', 'Valjean', 'Claquesous'] 3
# ['MlleBaptistine', 'Valjean', 'Montparnasse'] 3
# ['MlleBaptistine', 'Valjean', 'Toussaint'] 3
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Child1'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'Child2'] 4
# ['MlleBaptistine', 'Valjean', 'Thenardier', 'Brujon'] 4
# ['MlleBaptistine', 'Valjean', 'Gavroche', 'MmeHucheloup'] 4
# ['MmeMagloire', 'Myriel'] 2
# ['MmeMagloire', 'Myriel', 'Napoleon'] 3
# ['MmeMagloire', 'MlleBaptistine'] 2
# ['MmeMagloire'] 1
# ['MmeMagloire', 'Myriel', 'CountessDeLo'] 3
# ['MmeMagloire', 'Myriel', 'Geborand'] 3
# ['MmeMagloire', 'Myriel', 'Champtercier'] 3
# ['MmeMagloire', 'Myriel', 'Cravatte'] 3
# ['MmeMagloire', 'Myriel', 'Count'] 3
# ['MmeMagloire', 'Myriel', 'OldMan'] 3
# ['MmeMagloire', 'Valjean', 'Labarre'] 3
# ['MmeMagloire', 'Valjean'] 2
# ['MmeMagloire', 'Valjean', 'Marguerite'] 3
# ['MmeMagloire', 'Valjean', 'MmeDeR'] 3
# ['MmeMagloire', 'Valjean', 'Isabeau'] 3
# ['MmeMagloire', 'Valjean', 'Gervais'] 3
# ['MmeMagloire', 'Valjean', 'Fantine', 'Tholomyes'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Listolier'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Fameuil'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Blacheville'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Favourite'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Dahlia'] 4
# ['MmeMagloire', 'Valjean', 'Fantine', 'Zephine'] 4
# ['MmeMagloire', 'Valjean', 'Fantine'] 3
# ['MmeMagloire', 'Valjean', 'MmeThenardier'] 3
# ['MmeMagloire', 'Valjean', 'Thenardier'] 3
# ['MmeMagloire', 'Valjean', 'Cosette'] 3
# ['MmeMagloire', 'Valjean', 'Javert'] 3
# ['MmeMagloire', 'Valjean', 'Fauchelevent'] 3
# ['MmeMagloire', 'Valjean', 'Bamatabois'] 3
# ['MmeMagloire', 'Valjean', 'Fantine', 'Perpetue'] 4
# ['MmeMagloire', 'Valjean', 'Simplice'] 3
# ['MmeMagloire', 'Valjean', 'Scaufflaire'] 3
# ['MmeMagloire', 'Valjean', 'Woman1'] 3
# ['MmeMagloire', 'Valjean', 'Judge'] 3
# ['MmeMagloire', 'Valjean', 'Champmathieu'] 3
# ['MmeMagloire', 'Valjean', 'Brevet'] 3
# ['MmeMagloire', 'Valjean', 'Chenildieu'] 3
# ['MmeMagloire', 'Valjean', 'Cochepaille'] 3
# ['MmeMagloire', 'Valjean', 'Thenardier', 'Pontmercy'] 4
# ['MmeMagloire', 'Valjean', 'Thenardier', 'Boulatruelle'] 4
# ['MmeMagloire', 'Valjean', 'MmeThenardier', 'Eponine'] 4
# ['MmeMagloire', 'Valjean', 'MmeThenardier', 'Anzelma'] 4
# ['MmeMagloire', 'Valjean', 'Woman2'] 3
# ['MmeMagloire', 'Valjean', 'MotherInnocent'] 3
# ['MmeMagloire', 'Valjean', 'Fauchelevent', 'Gribier'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 5
# ['MmeMagloire', 'Valjean', 'Gavroche', 'MmeBurgon'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche'] 3
# ['MmeMagloire', 'Valjean', 'Gillenormand'] 3
# ['MmeMagloire', 'Valjean', 'MmeThenardier', 'Magnon'] 4
# ['MmeMagloire', 'Valjean', 'MlleGillenormand'] 3
# ['MmeMagloire', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 4
# ['MmeMagloire', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 4
# ['MmeMagloire', 'Valjean', 'Cosette', 'LtGillenormand'] 4
# ['MmeMagloire', 'Valjean', 'Marius'] 3
# ['MmeMagloire', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['MmeMagloire', 'Valjean', 'Enjolras'] 3
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Courfeyrac'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Bahorel'] 4
# ['MmeMagloire', 'Valjean', 'Bossuet'] 3
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Joly'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Grantaire'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 5
# ['MmeMagloire', 'Valjean', 'Gueulemer'] 3
# ['MmeMagloire', 'Valjean', 'Babet'] 3
# ['MmeMagloire', 'Valjean', 'Claquesous'] 3
# ['MmeMagloire', 'Valjean', 'Montparnasse'] 3
# ['MmeMagloire', 'Valjean', 'Toussaint'] 3
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Child1'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'Child2'] 4
# ['MmeMagloire', 'Valjean', 'Thenardier', 'Brujon'] 4
# ['MmeMagloire', 'Valjean', 'Gavroche', 'MmeHucheloup'] 4
# ['CountessDeLo', 'Myriel'] 2
# ['CountessDeLo', 'Myriel', 'Napoleon'] 3
# ['CountessDeLo', 'Myriel', 'MlleBaptistine'] 3
# ['CountessDeLo', 'Myriel', 'MmeMagloire'] 3
# ['CountessDeLo'] 1
# ['CountessDeLo', 'Myriel', 'Geborand'] 3
# ['CountessDeLo', 'Myriel', 'Champtercier'] 3
# ['CountessDeLo', 'Myriel', 'Cravatte'] 3
# ['CountessDeLo', 'Myriel', 'Count'] 3
# ['CountessDeLo', 'Myriel', 'OldMan'] 3
# ['CountessDeLo', 'Myriel', 'Valjean', 'Labarre'] 4
# ['CountessDeLo', 'Myriel', 'Valjean'] 3
# ['CountessDeLo', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gervais'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Cosette'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Javert'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Simplice'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Woman1'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Judge'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Brevet'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Woman2'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Marius'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Babet'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['CountessDeLo', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['Geborand', 'Myriel'] 2
# ['Geborand', 'Myriel', 'Napoleon'] 3
# ['Geborand', 'Myriel', 'MlleBaptistine'] 3
# ['Geborand', 'Myriel', 'MmeMagloire'] 3
# ['Geborand', 'Myriel', 'CountessDeLo'] 3
# ['Geborand'] 1
# ['Geborand', 'Myriel', 'Champtercier'] 3
# ['Geborand', 'Myriel', 'Cravatte'] 3
# ['Geborand', 'Myriel', 'Count'] 3
# ['Geborand', 'Myriel', 'OldMan'] 3
# ['Geborand', 'Myriel', 'Valjean', 'Labarre'] 4
# ['Geborand', 'Myriel', 'Valjean'] 3
# ['Geborand', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['Geborand', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gervais'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Fantine'] 4
# ['Geborand', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Cosette'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Javert'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Simplice'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Woman1'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Judge'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Brevet'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['Geborand', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['Geborand', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Woman2'] 4
# ['Geborand', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['Geborand', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Geborand', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['Geborand', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Geborand', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Marius'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['Geborand', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Babet'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['Geborand', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['Champtercier', 'Myriel'] 2
# ['Champtercier', 'Myriel', 'Napoleon'] 3
# ['Champtercier', 'Myriel', 'MlleBaptistine'] 3
# ['Champtercier', 'Myriel', 'MmeMagloire'] 3
# ['Champtercier', 'Myriel', 'CountessDeLo'] 3
# ['Champtercier', 'Myriel', 'Geborand'] 3
# ['Champtercier'] 1
# ['Champtercier', 'Myriel', 'Cravatte'] 3
# ['Champtercier', 'Myriel', 'Count'] 3
# ['Champtercier', 'Myriel', 'OldMan'] 3
# ['Champtercier', 'Myriel', 'Valjean', 'Labarre'] 4
# ['Champtercier', 'Myriel', 'Valjean'] 3
# ['Champtercier', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gervais'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Cosette'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Javert'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Simplice'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Woman1'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Judge'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Brevet'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Woman2'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Marius'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['Champtercier', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Babet'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['Champtercier', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['Cravatte', 'Myriel'] 2
# ['Cravatte', 'Myriel', 'Napoleon'] 3
# ['Cravatte', 'Myriel', 'MlleBaptistine'] 3
# ['Cravatte', 'Myriel', 'MmeMagloire'] 3
# ['Cravatte', 'Myriel', 'CountessDeLo'] 3
# ['Cravatte', 'Myriel', 'Geborand'] 3
# ['Cravatte', 'Myriel', 'Champtercier'] 3
# ['Cravatte'] 1
# ['Cravatte', 'Myriel', 'Count'] 3
# ['Cravatte', 'Myriel', 'OldMan'] 3
# ['Cravatte', 'Myriel', 'Valjean', 'Labarre'] 4
# ['Cravatte', 'Myriel', 'Valjean'] 3
# ['Cravatte', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gervais'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Cosette'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Javert'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Simplice'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Woman1'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Judge'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Brevet'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Woman2'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Marius'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['Cravatte', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Babet'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['Cravatte', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['Count', 'Myriel'] 2
# ['Count', 'Myriel', 'Napoleon'] 3
# ['Count', 'Myriel', 'MlleBaptistine'] 3
# ['Count', 'Myriel', 'MmeMagloire'] 3
# ['Count', 'Myriel', 'CountessDeLo'] 3
# ['Count', 'Myriel', 'Geborand'] 3
# ['Count', 'Myriel', 'Champtercier'] 3
# ['Count', 'Myriel', 'Cravatte'] 3
# ['Count'] 1
# ['Count', 'Myriel', 'OldMan'] 3
# ['Count', 'Myriel', 'Valjean', 'Labarre'] 4
# ['Count', 'Myriel', 'Valjean'] 3
# ['Count', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['Count', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['Count', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['Count', 'Myriel', 'Valjean', 'Gervais'] 4
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Count', 'Myriel', 'Valjean', 'Fantine'] 4
# ['Count', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['Count', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['Count', 'Myriel', 'Valjean', 'Cosette'] 4
# ['Count', 'Myriel', 'Valjean', 'Javert'] 4
# ['Count', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['Count', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['Count', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Count', 'Myriel', 'Valjean', 'Simplice'] 4
# ['Count', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['Count', 'Myriel', 'Valjean', 'Woman1'] 4
# ['Count', 'Myriel', 'Valjean', 'Judge'] 4
# ['Count', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['Count', 'Myriel', 'Valjean', 'Brevet'] 4
# ['Count', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['Count', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['Count', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['Count', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['Count', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['Count', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['Count', 'Myriel', 'Valjean', 'Woman2'] 4
# ['Count', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['Count', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['Count', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['Count', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Count', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['Count', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Count', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Count', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['Count', 'Myriel', 'Valjean', 'Marius'] 4
# ['Count', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['Count', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['Count', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['Count', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['Count', 'Myriel', 'Valjean', 'Babet'] 4
# ['Count', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['Count', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['Count', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['Count', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['Count', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['OldMan', 'Myriel'] 2
# ['OldMan', 'Myriel', 'Napoleon'] 3
# ['OldMan', 'Myriel', 'MlleBaptistine'] 3
# ['OldMan', 'Myriel', 'MmeMagloire'] 3
# ['OldMan', 'Myriel', 'CountessDeLo'] 3
# ['OldMan', 'Myriel', 'Geborand'] 3
# ['OldMan', 'Myriel', 'Champtercier'] 3
# ['OldMan', 'Myriel', 'Cravatte'] 3
# ['OldMan', 'Myriel', 'Count'] 3
# ['OldMan'] 1
# ['OldMan', 'Myriel', 'Valjean', 'Labarre'] 4
# ['OldMan', 'Myriel', 'Valjean'] 3
# ['OldMan', 'Myriel', 'Valjean', 'Marguerite'] 4
# ['OldMan', 'Myriel', 'Valjean', 'MmeDeR'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Isabeau'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gervais'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Tholomyes'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Listolier'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Favourite'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Zephine'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Fantine'] 4
# ['OldMan', 'Myriel', 'Valjean', 'MmeThenardier'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Thenardier'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Cosette'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Javert'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Fauchelevent'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Bamatabois'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Simplice'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Scaufflaire'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Woman1'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Judge'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Champmathieu'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Brevet'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Chenildieu'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Cochepaille'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Thenardier', 'Pontmercy'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Thenardier', 'Boulatruelle'] 5
# ['OldMan', 'Myriel', 'Valjean', 'MmeThenardier', 'Eponine'] 5
# ['OldMan', 'Myriel', 'Valjean', 'MmeThenardier', 'Anzelma'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Woman2'] 4
# ['OldMan', 'Myriel', 'Valjean', 'MotherInnocent'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 6
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'MmeBurgon'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gillenormand'] 4
# ['OldMan', 'Myriel', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['OldMan', 'Myriel', 'Valjean', 'MlleGillenormand'] 4
# ['OldMan', 'Myriel', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['OldMan', 'Myriel', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Cosette', 'LtGillenormand'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Marius'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gillenormand', 'BaronessT'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Enjolras'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Combeferre'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Prouvaire'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Feuilly'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Courfeyrac'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Bahorel'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Bossuet'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Joly'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Grantaire'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 6
# ['OldMan', 'Myriel', 'Valjean', 'Gueulemer'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Babet'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Claquesous'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Montparnasse'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Toussaint'] 4
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Child1'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'Child2'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Thenardier', 'Brujon'] 5
# ['OldMan', 'Myriel', 'Valjean', 'Gavroche', 'MmeHucheloup'] 5
# ['Labarre', 'Valjean', 'Myriel'] 3
# ['Labarre', 'Valjean', 'Myriel', 'Napoleon'] 4
# ['Labarre', 'Valjean', 'MlleBaptistine'] 3
# ['Labarre', 'Valjean', 'MmeMagloire'] 3
# ['Labarre', 'Valjean', 'Myriel', 'CountessDeLo'] 4
# ['Labarre', 'Valjean', 'Myriel', 'Geborand'] 4
# ['Labarre', 'Valjean', 'Myriel', 'Champtercier'] 4
# ['Labarre', 'Valjean', 'Myriel', 'Cravatte'] 4
# ['Labarre', 'Valjean', 'Myriel', 'Count'] 4
# ['Labarre', 'Valjean', 'Myriel', 'OldMan'] 4
# ['Labarre'] 1
# ['Labarre', 'Valjean'] 2
# ['Labarre', 'Valjean', 'Marguerite'] 3
# ['Labarre', 'Valjean', 'MmeDeR'] 3
# ['Labarre', 'Valjean', 'Isabeau'] 3
# ['Labarre', 'Valjean', 'Gervais'] 3
# ['Labarre', 'Valjean', 'Fantine', 'Tholomyes'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Listolier'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Fameuil'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Blacheville'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Favourite'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Dahlia'] 4
# ['Labarre', 'Valjean', 'Fantine', 'Zephine'] 4
# ['Labarre', 'Valjean', 'Fantine'] 3
# ['Labarre', 'Valjean', 'MmeThenardier'] 3
# ['Labarre', 'Valjean', 'Thenardier'] 3
# ['Labarre', 'Valjean', 'Cosette'] 3
# ['Labarre', 'Valjean', 'Javert'] 3
# ['Labarre', 'Valjean', 'Fauchelevent'] 3
# ['Labarre', 'Valjean', 'Bamatabois'] 3
# ['Labarre', 'Valjean', 'Fantine', 'Perpetue'] 4
# ['Labarre', 'Valjean', 'Simplice'] 3
# ['Labarre', 'Valjean', 'Scaufflaire'] 3
# ['Labarre', 'Valjean', 'Woman1'] 3
# ['Labarre', 'Valjean', 'Judge'] 3
# ['Labarre', 'Valjean', 'Champmathieu'] 3
# ['Labarre', 'Valjean', 'Brevet'] 3
# ['Labarre', 'Valjean', 'Chenildieu'] 3
# ['Labarre', 'Valjean', 'Cochepaille'] 3
# ['Labarre', 'Valjean', 'Thenardier', 'Pontmercy'] 4
# ['Labarre', 'Valjean', 'Thenardier', 'Boulatruelle'] 4
# ['Labarre', 'Valjean', 'MmeThenardier', 'Eponine'] 4
# ['Labarre', 'Valjean', 'MmeThenardier', 'Anzelma'] 4
# ['Labarre', 'Valjean', 'Woman2'] 3
# ['Labarre', 'Valjean', 'MotherInnocent'] 3
# ['Labarre', 'Valjean', 'Fauchelevent', 'Gribier'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 5
# ['Labarre', 'Valjean', 'Gavroche', 'MmeBurgon'] 4
# ['Labarre', 'Valjean', 'Gavroche'] 3
# ['Labarre', 'Valjean', 'Gillenormand'] 3
# ['Labarre', 'Valjean', 'MmeThenardier', 'Magnon'] 4
# ['Labarre', 'Valjean', 'MlleGillenormand'] 3
# ['Labarre', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 4
# ['Labarre', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 4
# ['Labarre', 'Valjean', 'Cosette', 'LtGillenormand'] 4
# ['Labarre', 'Valjean', 'Marius'] 3
# ['Labarre', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['Labarre', 'Valjean', 'Enjolras'] 3
# ['Labarre', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Courfeyrac'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Bahorel'] 4
# ['Labarre', 'Valjean', 'Bossuet'] 3
# ['Labarre', 'Valjean', 'Gavroche', 'Joly'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Grantaire'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 5
# ['Labarre', 'Valjean', 'Gueulemer'] 3
# ['Labarre', 'Valjean', 'Babet'] 3
# ['Labarre', 'Valjean', 'Claquesous'] 3
# ['Labarre', 'Valjean', 'Montparnasse'] 3
# ['Labarre', 'Valjean', 'Toussaint'] 3
# ['Labarre', 'Valjean', 'Gavroche', 'Child1'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'Child2'] 4
# ['Labarre', 'Valjean', 'Thenardier', 'Brujon'] 4
# ['Labarre', 'Valjean', 'Gavroche', 'MmeHucheloup'] 4
# ['Valjean', 'Myriel'] 2
# ['Valjean', 'Myriel', 'Napoleon'] 3
# ['Valjean', 'MlleBaptistine'] 2
# ['Valjean', 'MmeMagloire'] 2
# ['Valjean', 'Myriel', 'CountessDeLo'] 3
# ['Valjean', 'Myriel', 'Geborand'] 3
# ['Valjean', 'Myriel', 'Champtercier'] 3
# ['Valjean', 'Myriel', 'Cravatte'] 3
# ['Valjean', 'Myriel', 'Count'] 3
# ['Valjean', 'Myriel', 'OldMan'] 3
# ['Valjean', 'Labarre'] 2
# ['Valjean'] 1
# ['Valjean', 'Marguerite'] 2
# ['Valjean', 'MmeDeR'] 2
# ['Valjean', 'Isabeau'] 2
# ['Valjean', 'Gervais'] 2
# ['Valjean', 'Fantine', 'Tholomyes'] 3
# ['Valjean', 'Fantine', 'Listolier'] 3
# ['Valjean', 'Fantine', 'Fameuil'] 3
# ['Valjean', 'Fantine', 'Blacheville'] 3
# ['Valjean', 'Fantine', 'Favourite'] 3
# ['Valjean', 'Fantine', 'Dahlia'] 3
# ['Valjean', 'Fantine', 'Zephine'] 3
# ['Valjean', 'Fantine'] 2
# ['Valjean', 'MmeThenardier'] 2
# ['Valjean', 'Thenardier'] 2
# ['Valjean', 'Cosette'] 2
# ['Valjean', 'Javert'] 2
# ['Valjean', 'Fauchelevent'] 2
# ['Valjean', 'Bamatabois'] 2
# ['Valjean', 'Fantine', 'Perpetue'] 3
# ['Valjean', 'Simplice'] 2
# ['Valjean', 'Scaufflaire'] 2
# ['Valjean', 'Woman1'] 2
# ['Valjean', 'Judge'] 2
# ['Valjean', 'Champmathieu'] 2
# ['Valjean', 'Brevet'] 2
# ['Valjean', 'Chenildieu'] 2
# ['Valjean', 'Cochepaille'] 2
# ['Valjean', 'Thenardier', 'Pontmercy'] 3
# ['Valjean', 'Thenardier', 'Boulatruelle'] 3
# ['Valjean', 'MmeThenardier', 'Eponine'] 3
# ['Valjean', 'MmeThenardier', 'Anzelma'] 3
# ['Valjean', 'Woman2'] 2
# ['Valjean', 'MotherInnocent'] 2
# ['Valjean', 'Fauchelevent', 'Gribier'] 3
# ['Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 4
# ['Valjean', 'Gavroche', 'MmeBurgon'] 3
# ['Valjean', 'Gavroche'] 2
# ['Valjean', 'Gillenormand'] 2
# ['Valjean', 'MmeThenardier', 'Magnon'] 3
# ['Valjean', 'MlleGillenormand'] 2
# ['Valjean', 'MlleGillenormand', 'MmePontmercy'] 3
# ['Valjean', 'MlleGillenormand', 'MlleVaubois'] 3
# ['Valjean', 'Cosette', 'LtGillenormand'] 3
# ['Valjean', 'Marius'] 2
# ['Valjean', 'Gillenormand', 'BaronessT'] 3
# ['Valjean', 'Gavroche', 'Mabeuf'] 3
# ['Valjean', 'Enjolras'] 2
# ['Valjean', 'Gavroche', 'Combeferre'] 3
# ['Valjean', 'Gavroche', 'Prouvaire'] 3
# ['Valjean', 'Gavroche', 'Feuilly'] 3
# ['Valjean', 'Gavroche', 'Courfeyrac'] 3
# ['Valjean', 'Gavroche', 'Bahorel'] 3
# ['Valjean', 'Bossuet'] 2
# ['Valjean', 'Gavroche', 'Joly'] 3
# ['Valjean', 'Gavroche', 'Grantaire'] 3
# ['Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 4
# ['Valjean', 'Gueulemer'] 2
# ['Valjean', 'Babet'] 2
# ['Valjean', 'Claquesous'] 2
# ['Valjean', 'Montparnasse'] 2
# ['Valjean', 'Toussaint'] 2
# ['Valjean', 'Gavroche', 'Child1'] 3
# ['Valjean', 'Gavroche', 'Child2'] 3
# ['Valjean', 'Thenardier', 'Brujon'] 3
# ['Valjean', 'Gavroche', 'MmeHucheloup'] 3
# ['Marguerite', 'Valjean', 'Myriel'] 3
# ['Marguerite', 'Valjean', 'Myriel', 'Napoleon'] 4
# ['Marguerite', 'Valjean', 'MlleBaptistine'] 3
# ['Marguerite', 'Valjean', 'MmeMagloire'] 3
# ['Marguerite', 'Valjean', 'Myriel', 'CountessDeLo'] 4
# ['Marguerite', 'Valjean', 'Myriel', 'Geborand'] 4
# ['Marguerite', 'Valjean', 'Myriel', 'Champtercier'] 4
# ['Marguerite', 'Valjean', 'Myriel', 'Cravatte'] 4
# ['Marguerite', 'Valjean', 'Myriel', 'Count'] 4
# ['Marguerite', 'Valjean', 'Myriel', 'OldMan'] 4
# ['Marguerite', 'Valjean', 'Labarre'] 3
# ['Marguerite', 'Valjean'] 2
# ['Marguerite'] 1
# ['Marguerite', 'Valjean', 'MmeDeR'] 3
# ['Marguerite', 'Valjean', 'Isabeau'] 3
# ['Marguerite', 'Valjean', 'Gervais'] 3
# ['Marguerite', 'Fantine', 'Tholomyes'] 3
# ['Marguerite', 'Fantine', 'Listolier'] 3
# ['Marguerite', 'Fantine', 'Fameuil'] 3
# ['Marguerite', 'Fantine', 'Blacheville'] 3
# ['Marguerite', 'Fantine', 'Favourite'] 3
# ['Marguerite', 'Fantine', 'Dahlia'] 3
# ['Marguerite', 'Fantine', 'Zephine'] 3
# ['Marguerite', 'Fantine'] 2
# ['Marguerite', 'Valjean', 'MmeThenardier'] 3
# ['Marguerite', 'Valjean', 'Thenardier'] 3
# ['Marguerite', 'Valjean', 'Cosette'] 3
# ['Marguerite', 'Valjean', 'Javert'] 3
# ['Marguerite', 'Valjean', 'Fauchelevent'] 3
# ['Marguerite', 'Valjean', 'Bamatabois'] 3
# ['Marguerite', 'Fantine', 'Perpetue'] 3
# ['Marguerite', 'Valjean', 'Simplice'] 3
# ['Marguerite', 'Valjean', 'Scaufflaire'] 3
# ['Marguerite', 'Valjean', 'Woman1'] 3
# ['Marguerite', 'Valjean', 'Judge'] 3
# ['Marguerite', 'Valjean', 'Champmathieu'] 3
# ['Marguerite', 'Valjean', 'Brevet'] 3
# ['Marguerite', 'Valjean', 'Chenildieu'] 3
# ['Marguerite', 'Valjean', 'Cochepaille'] 3
# ['Marguerite', 'Valjean', 'Thenardier', 'Pontmercy'] 4
# ['Marguerite', 'Valjean', 'Thenardier', 'Boulatruelle'] 4
# ['Marguerite', 'Valjean', 'MmeThenardier', 'Eponine'] 4
# ['Marguerite', 'Valjean', 'MmeThenardier', 'Anzelma'] 4
# ['Marguerite', 'Valjean', 'Woman2'] 3
# ['Marguerite', 'Valjean', 'MotherInnocent'] 3
# ['Marguerite', 'Valjean', 'Fauchelevent', 'Gribier'] 4
# ['Marguerite', 'Valjean', 'Gavroche', 'MmeBurgon', 'Jondrette'] 5
# ['Marguerite', 'Valjean', 'Gavroche', 'MmeBurgon'] 4
# ['Marguerite', 'Valjean', 'Gavroche'] 3
# ['Marguerite', 'Valjean', 'Gillenormand'] 3
# ['Marguerite', 'Valjean', 'MmeThenardier', 'Magnon'] 4
# ['Marguerite', 'Valjean', 'MlleGillenormand'] 3
# ['Marguerite', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 4
# ['Marguerite', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 4
# ['Marguerite', 'Valjean', 'Cosette', 'LtGillenormand'] 4
# ['Marguerite', 'Valjean', 'Marius'] 3
# ['Marguerite', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['Marguerite', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['Marguerite', 'Valjean', 'Enjolras'] 3
# ['Marguerite', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['Marguerite', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['Marguerite', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ...
# ['Toussaint', 'Valjean', 'Marius'] 3
# ['Toussaint', 'Valjean', 'Gillenormand', 'BaronessT'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Mabeuf'] 4
# ['Toussaint', 'Valjean', 'Enjolras'] 3
# ['Toussaint', 'Valjean', 'Gavroche', 'Combeferre'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Prouvaire'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Feuilly'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Courfeyrac'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Bahorel'] 4
# ['Toussaint', 'Valjean', 'Bossuet'] 3
# ['Toussaint', 'Valjean', 'Gavroche', 'Joly'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Grantaire'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 5
# ['Toussaint', 'Valjean', 'Gueulemer'] 3
# ['Toussaint', 'Valjean', 'Babet'] 3
# ['Toussaint', 'Valjean', 'Claquesous'] 3
# ['Toussaint', 'Valjean', 'Montparnasse'] 3
# ['Toussaint'] 1
# ['Toussaint', 'Valjean', 'Gavroche', 'Child1'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'Child2'] 4
# ['Toussaint', 'Valjean', 'Thenardier', 'Brujon'] 4
# ['Toussaint', 'Valjean', 'Gavroche', 'MmeHucheloup'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Myriel'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'Napoleon'] 5
# ['Child1', 'Gavroche', 'Valjean', 'MlleBaptistine'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MmeMagloire'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'CountessDeLo'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'Geborand'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'Champtercier'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'Cravatte'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'Count'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Myriel', 'OldMan'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Labarre'] 4
# ['Child1', 'Gavroche', 'Valjean'] 3
# ['Child1', 'Gavroche', 'Valjean', 'Marguerite'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MmeDeR'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Isabeau'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Gervais'] 4
# ['Child1', 'Gavroche', 'Marius', 'Tholomyes'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Fantine'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MmeThenardier'] 4
# ['Child1', 'Gavroche', 'Thenardier'] 3
# ['Child1', 'Gavroche', 'Valjean', 'Cosette'] 4
# ['Child1', 'Gavroche', 'Javert'] 3
# ['Child1', 'Gavroche', 'Valjean', 'Fauchelevent'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Bamatabois'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Child1', 'Gavroche', 'Valjean', 'Simplice'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Scaufflaire'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Woman1'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Judge'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Champmathieu'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Brevet'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Chenildieu'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Cochepaille'] 4
# ['Child1', 'Gavroche', 'Thenardier', 'Pontmercy'] 4
# ['Child1', 'Gavroche', 'Thenardier', 'Boulatruelle'] 4
# ['Child1', 'Gavroche', 'Thenardier', 'Eponine'] 4
# ['Child1', 'Gavroche', 'Thenardier', 'Anzelma'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Woman2'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MotherInnocent'] 4
# ['Child1', 'Gavroche', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Child1', 'Gavroche', 'MmeBurgon', 'Jondrette'] 4
# ['Child1', 'Gavroche', 'MmeBurgon'] 3
# ['Child1', 'Gavroche'] 2
# ['Child1', 'Gavroche', 'Valjean', 'Gillenormand'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Child1', 'Gavroche', 'Valjean', 'MlleGillenormand'] 4
# ['Child1', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Child1', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Child1', 'Gavroche', 'Marius', 'LtGillenormand'] 4
# ['Child1', 'Gavroche', 'Marius'] 3
# ['Child1', 'Gavroche', 'Marius', 'BaronessT'] 4
# ['Child1', 'Gavroche', 'Mabeuf'] 3
# ['Child1', 'Gavroche', 'Enjolras'] 3
# ['Child1', 'Gavroche', 'Combeferre'] 3
# ['Child1', 'Gavroche', 'Prouvaire'] 3
# ['Child1', 'Gavroche', 'Feuilly'] 3
# ['Child1', 'Gavroche', 'Courfeyrac'] 3
# ['Child1', 'Gavroche', 'Bahorel'] 3
# ['Child1', 'Gavroche', 'Bossuet'] 3
# ['Child1', 'Gavroche', 'Joly'] 3
# ['Child1', 'Gavroche', 'Grantaire'] 3
# ['Child1', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 4
# ['Child1', 'Gavroche', 'Gueulemer'] 3
# ['Child1', 'Gavroche', 'Babet'] 3
# ['Child1', 'Gavroche', 'Valjean', 'Claquesous'] 4
# ['Child1', 'Gavroche', 'Montparnasse'] 3
# ['Child1', 'Gavroche', 'Valjean', 'Toussaint'] 4
# ['Child1'] 1
# ['Child1', 'Child2'] 2
# ['Child1', 'Gavroche', 'Brujon'] 3
# ['Child1', 'Gavroche', 'MmeHucheloup'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Myriel'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'Napoleon'] 5
# ['Child2', 'Gavroche', 'Valjean', 'MlleBaptistine'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MmeMagloire'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'CountessDeLo'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'Geborand'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'Champtercier'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'Cravatte'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'Count'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Myriel', 'OldMan'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Labarre'] 4
# ['Child2', 'Gavroche', 'Valjean'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Marguerite'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MmeDeR'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Isabeau'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Gervais'] 4
# ['Child2', 'Gavroche', 'Marius', 'Tholomyes'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Listolier'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Favourite'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Zephine'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Fantine'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MmeThenardier'] 4
# ['Child2', 'Gavroche', 'Thenardier'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Cosette'] 4
# ['Child2', 'Gavroche', 'Javert'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Fauchelevent'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Bamatabois'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['Child2', 'Gavroche', 'Valjean', 'Simplice'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Scaufflaire'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Woman1'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Judge'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Champmathieu'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Brevet'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Chenildieu'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Cochepaille'] 4
# ['Child2', 'Gavroche', 'Thenardier', 'Pontmercy'] 4
# ['Child2', 'Gavroche', 'Thenardier', 'Boulatruelle'] 4
# ['Child2', 'Gavroche', 'Thenardier', 'Eponine'] 4
# ['Child2', 'Gavroche', 'Thenardier', 'Anzelma'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Woman2'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MotherInnocent'] 4
# ['Child2', 'Gavroche', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Child2', 'Gavroche', 'MmeBurgon', 'Jondrette'] 4
# ['Child2', 'Gavroche', 'MmeBurgon'] 3
# ['Child2', 'Gavroche'] 2
# ['Child2', 'Gavroche', 'Valjean', 'Gillenormand'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['Child2', 'Gavroche', 'Valjean', 'MlleGillenormand'] 4
# ['Child2', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['Child2', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Child2', 'Gavroche', 'Marius', 'LtGillenormand'] 4
# ['Child2', 'Gavroche', 'Marius'] 3
# ['Child2', 'Gavroche', 'Marius', 'BaronessT'] 4
# ['Child2', 'Gavroche', 'Mabeuf'] 3
# ['Child2', 'Gavroche', 'Enjolras'] 3
# ['Child2', 'Gavroche', 'Combeferre'] 3
# ['Child2', 'Gavroche', 'Prouvaire'] 3
# ['Child2', 'Gavroche', 'Feuilly'] 3
# ['Child2', 'Gavroche', 'Courfeyrac'] 3
# ['Child2', 'Gavroche', 'Bahorel'] 3
# ['Child2', 'Gavroche', 'Bossuet'] 3
# ['Child2', 'Gavroche', 'Joly'] 3
# ['Child2', 'Gavroche', 'Grantaire'] 3
# ['Child2', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 4
# ['Child2', 'Gavroche', 'Gueulemer'] 3
# ['Child2', 'Gavroche', 'Babet'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Claquesous'] 4
# ['Child2', 'Gavroche', 'Montparnasse'] 3
# ['Child2', 'Gavroche', 'Valjean', 'Toussaint'] 4
# ['Child2', 'Child1'] 2
# ['Child2'] 1
# ['Child2', 'Gavroche', 'Brujon'] 3
# ['Child2', 'Gavroche', 'MmeHucheloup'] 3
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'Napoleon'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'MlleBaptistine'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'MmeMagloire'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'CountessDeLo'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'Geborand'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'Champtercier'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'Cravatte'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'Count'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Myriel', 'OldMan'] 5
# ['Brujon', 'Thenardier', 'Valjean', 'Labarre'] 4
# ['Brujon', 'Thenardier', 'Valjean'] 3
# ['Brujon', 'Thenardier', 'Valjean', 'Marguerite'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'MmeDeR'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Isabeau'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Gervais'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Tholomyes'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Listolier'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Fameuil'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Blacheville'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Favourite'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Dahlia'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Zephine'] 4
# ['Brujon', 'Thenardier', 'Fantine'] 3
# ['Brujon', 'Thenardier', 'MmeThenardier'] 3
# ['Brujon', 'Thenardier'] 2
# ['Brujon', 'Thenardier', 'Cosette'] 3
# ['Brujon', 'Thenardier', 'Javert'] 3
# ['Brujon', 'Thenardier', 'Valjean', 'Fauchelevent'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Bamatabois'] 4
# ['Brujon', 'Thenardier', 'Fantine', 'Perpetue'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Simplice'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Scaufflaire'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Woman1'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Judge'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Champmathieu'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Brevet'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Chenildieu'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Cochepaille'] 4
# ['Brujon', 'Thenardier', 'Pontmercy'] 3
# ['Brujon', 'Thenardier', 'Boulatruelle'] 3
# ['Brujon', 'Eponine'] 2
# ['Brujon', 'Thenardier', 'Anzelma'] 3
# ['Brujon', 'Thenardier', 'Valjean', 'Woman2'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'MotherInnocent'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['Brujon', 'Gavroche', 'MmeBurgon', 'Jondrette'] 4
# ['Brujon', 'Gavroche', 'MmeBurgon'] 3
# ['Brujon', 'Gavroche'] 2
# ['Brujon', 'Thenardier', 'Valjean', 'Gillenormand'] 4
# ['Brujon', 'Thenardier', 'MmeThenardier', 'Magnon'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'MlleGillenormand'] 4
# ['Brujon', 'Thenardier', 'Pontmercy', 'MmePontmercy'] 4
# ['Brujon', 'Thenardier', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['Brujon', 'Thenardier', 'Cosette', 'LtGillenormand'] 4
# ['Brujon', 'Thenardier', 'Marius'] 3
# ['Brujon', 'Thenardier', 'Marius', 'BaronessT'] 4
# ['Brujon', 'Eponine', 'Mabeuf'] 3
# ['Brujon', 'Gavroche', 'Enjolras'] 3
# ['Brujon', 'Gavroche', 'Combeferre'] 3
# ['Brujon', 'Gavroche', 'Prouvaire'] 3
# ['Brujon', 'Gavroche', 'Feuilly'] 3
# ['Brujon', 'Eponine', 'Courfeyrac'] 3
# ['Brujon', 'Gavroche', 'Bahorel'] 3
# ['Brujon', 'Gavroche', 'Bossuet'] 3
# ['Brujon', 'Gavroche', 'Joly'] 3
# ['Brujon', 'Gavroche', 'Grantaire'] 3
# ['Brujon', 'Eponine', 'Mabeuf', 'MotherPlutarch'] 4
# ['Brujon', 'Gueulemer'] 2
# ['Brujon', 'Babet'] 2
# ['Brujon', 'Claquesous'] 2
# ['Brujon', 'Montparnasse'] 2
# ['Brujon', 'Thenardier', 'Valjean', 'Toussaint'] 4
# ['Brujon', 'Gavroche', 'Child1'] 3
# ['Brujon', 'Gavroche', 'Child2'] 3
# ['Brujon'] 1
# ['Brujon', 'Gavroche', 'MmeHucheloup'] 3
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'Napoleon'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MlleBaptistine'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MmeMagloire'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'CountessDeLo'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'Geborand'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'Champtercier'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'Cravatte'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'Count'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Myriel', 'OldMan'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Labarre'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean'] 3
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Marguerite'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MmeDeR'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Isabeau'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Gervais'] 4
# ['MmeHucheloup', 'Gavroche', 'Marius', 'Tholomyes'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Listolier'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Fameuil'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Blacheville'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Favourite'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Dahlia'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Zephine'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MmeThenardier'] 4
# ['MmeHucheloup', 'Gavroche', 'Thenardier'] 3
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Cosette'] 4
# ['MmeHucheloup', 'Gavroche', 'Javert'] 3
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fauchelevent'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Bamatabois'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fantine', 'Perpetue'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Simplice'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Scaufflaire'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Woman1'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Judge'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Champmathieu'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Brevet'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Chenildieu'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Cochepaille'] 4
# ['MmeHucheloup', 'Gavroche', 'Thenardier', 'Pontmercy'] 4
# ['MmeHucheloup', 'Gavroche', 'Thenardier', 'Boulatruelle'] 4
# ['MmeHucheloup', 'Courfeyrac', 'Eponine'] 3
# ['MmeHucheloup', 'Gavroche', 'Thenardier', 'Anzelma'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Woman2'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MotherInnocent'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Fauchelevent', 'Gribier'] 5
# ['MmeHucheloup', 'Gavroche', 'MmeBurgon', 'Jondrette'] 4
# ['MmeHucheloup', 'Gavroche', 'MmeBurgon'] 3
# ['MmeHucheloup', 'Gavroche'] 2
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Gillenormand'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MmeThenardier', 'Magnon'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MlleGillenormand'] 4
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MmePontmercy'] 5
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'MlleGillenormand', 'MlleVaubois'] 5
# ['MmeHucheloup', 'Gavroche', 'Marius', 'LtGillenormand'] 4
# ['MmeHucheloup', 'Gavroche', 'Marius'] 3
# ['MmeHucheloup', 'Gavroche', 'Marius', 'BaronessT'] 4
# ['MmeHucheloup', 'Gavroche', 'Mabeuf'] 3
# ['MmeHucheloup', 'Enjolras'] 2
# ['MmeHucheloup', 'Gavroche', 'Combeferre'] 3
# ['MmeHucheloup', 'Gavroche', 'Prouvaire'] 3
# ['MmeHucheloup', 'Gavroche', 'Feuilly'] 3
# ['MmeHucheloup', 'Courfeyrac'] 2
# ['MmeHucheloup', 'Bahorel'] 2
# ['MmeHucheloup', 'Bossuet'] 2
# ['MmeHucheloup', 'Joly'] 2
# ['MmeHucheloup', 'Grantaire'] 2
# ['MmeHucheloup', 'Gavroche', 'Mabeuf', 'MotherPlutarch'] 4
# ['MmeHucheloup', 'Gavroche', 'Gueulemer'] 3
# ['MmeHucheloup', 'Gavroche', 'Babet'] 3
# ['MmeHucheloup', 'Enjolras', 'Claquesous'] 3
# ['MmeHucheloup', 'Gavroche', 'Montparnasse'] 3
# ['MmeHucheloup', 'Gavroche', 'Valjean', 'Toussaint'] 4
# ['MmeHucheloup', 'Gavroche', 'Child1'] 3
# ['MmeHucheloup', 'Gavroche', 'Child2'] 3
# ['MmeHucheloup', 'Gavroche', 'Brujon'] 3
# ['MmeHucheloup'] 1

# %% [markdown]
# ### Diameter of the graph

# %%
print("The diamter of the graph is: ",nx.diameter(fil))
# Out:
# The diamter of the graph is:  5

# %% [markdown]
# ### Network density

# %%
print("The network density of the graph is: ",nx.density(fil))
# Out:
# The network density of the graph is:  0.08680792891319207

# %% [markdown]
# ### Top edges in terms of edge-betweenness

# %%
# calculate the edge betweenness
ed_bw = nx.edge_betweenness_centrality(fil)
# Sort in descending order
all_scores = sorted(ed_bw.values(),reverse = True)
# Select top ten
top10_scores = all_scores[0:10]
for i in top10_scores:
    for j in ed_bw.keys():
        if ed_bw[j] == i :
            print(j,"---->",ed_bw[j])
            break
# Out:
# ('Myriel', 'Valjean') ----> 0.18318523581681478
# ('Valjean', 'Gavroche') ----> 0.08298247284530984
# ('Valjean', 'Fantine') ----> 0.07620427321283742
# ('MmeBurgon', 'Gavroche') ----> 0.05126452494873548
# ('Valjean', 'MlleGillenormand') ----> 0.045040847642522294
# ('Valjean', 'Marius') ----> 0.04430736242032529
# ('Tholomyes', 'Marius') ----> 0.04426433760397012
# ('Valjean', 'Bossuet') ----> 0.04227784539256207
# ('Valjean', 'Enjolras') ----> 0.03934925768953828
# ('Valjean', 'Fauchelevent') ----> 0.03638992586361008

# %% [markdown]
# ### Ego network for the top 3 nodes ( in terms of degree centrality) and their alters

# %%
# Calculate the degree centrality
all_degree = nx.degree_centrality(fil)
# Sort in descneding order
all_dscores = sorted(all_degree.values(),reverse = True)
# Select top three
top3_dscores = all_dscores[0:3]
# draw th ego networks
k = 0
l = 0 
temp = []
for i in top3_dscores:
    for j in all_degree.keys():
        if all_degree[j] == i :
            print(j,"\n")
            temp.append(j)
            ego = nx.generators.ego.ego_graph(fil,j,1)
            print("The list of alters is: ",ego.nodes()-[i])
            nx.draw_networkx(ego,pos=nx.spring_layout(fil))
            plt.show()
            break
# Out:
# Valjean
#
# The list of alters is:  {'MlleBaptistine', 'Gillenormand', 'Javert', 'Brevet', 'Gueulemer', 'Valjean', 'Montparnasse', 'Cosette', 'Myriel', 'MmeDeR', 'Toussaint', 'Claquesous', 'Champmathieu', 'Woman1', 'Enjolras', 'Fauchelevent', 'Gervais', 'Judge', 'Labarre', 'Isabeau', 'Woman2', 'Cochepaille', 'MlleGillenormand', 'Marguerite', 'Babet', 'Bamatabois', 'Chenildieu', 'Simplice', 'MmeThenardier', 'MotherInnocent', 'MmeMagloire', 'Scaufflaire', 'Thenardier', 'Marius', 'Bossuet', 'Gavroche', 'Fantine'}
# Gavroche
#
# The list of alters is:  {'MmeHucheloup', 'Javert', 'Brujon', 'Prouvaire', 'Gueulemer', 'Valjean', 'Montparnasse', 'Child1', 'Feuilly', 'Grantaire', 'MmeBurgon', 'Enjolras', 'Mabeuf', 'Joly', 'Bahorel', 'Babet', 'Courfeyrac', 'Thenardier', 'Gavroche', 'Marius', 'Bossuet', 'Child2', 'Combeferre'}
# Marius
#
# The list of alters is:  {'Gillenormand', 'Valjean', 'Feuilly', 'Cosette', 'LtGillenormand', 'Eponine', 'Enjolras', 'BaronessT', 'Mabeuf', 'Joly', 'Pontmercy', 'MlleGillenormand', 'Bahorel', 'Courfeyrac', 'Thenardier', 'Tholomyes', 'Marius', 'Bossuet', 'Gavroche', 'Combeferre'}

# %% [markdown]
# ### Similarity between nodes.
# #### Top 5 pairs in terms of structural similarity

# %%
from operator import itemgetter
G = fil

    # find node with largest degree
node_and_degree = G.degree()
(largest_hub, degree) = sorted(node_and_degree, key=itemgetter(1))[-1]
    # Create ego graph of main hub
hub_ego = nx.ego_graph(G, largest_hub)
print(hub_ego.nodes() - [largest_hub])
    # Draw graph
pos = nx.spring_layout(hub_ego)
nx.draw(hub_ego, pos, node_color='b', node_size=50, with_labels=False)
    # Draw ego as large and red
nx.draw_networkx_nodes(hub_ego, pos, nodelist=[largest_hub], node_size=300, node_color='r')
plt.show()

G = fil
print(temp[1])
    # find node with largest degree
node_and_degree = G.degree()
(largest_hub, degree) = sorted(node_and_degree, key=itemgetter(1))[-2]
    # Create ego graph of main hub
hub_ego = nx.ego_graph(G, largest_hub)
print(hub_ego.nodes() - [largest_hub])
    # Draw graph
pos = nx.spring_layout(hub_ego)
nx.draw(hub_ego, pos, node_color='b', node_size=50, with_labels=False)
    # Draw ego as large and red
nx.draw_networkx_nodes(hub_ego, pos, nodelist=[largest_hub], node_size=300, node_color='r')
plt.show()

G = fil
print(temp[2])
    # find node with largest degree
node_and_degree = G.degree()
(largest_hub, degree) = sorted(node_and_degree, key=itemgetter(1))[-3]
    # Create ego graph of main hub
hub_ego = nx.ego_graph(G, largest_hub)
print(hub_ego.nodes() - [largest_hub])
    # Draw graph
pos = nx.spring_layout(hub_ego)
nx.draw(hub_ego, pos, node_color='b', node_size=50, with_labels=False)
    # Draw ego as large and red
nx.draw_networkx_nodes(hub_ego, pos, nodelist=[largest_hub], node_size=300, node_color='r')
plt.show()
# Out:
# {'MlleBaptistine', 'Gillenormand', 'Javert', 'Brevet', 'Gueulemer', 'Montparnasse', 'Cosette', 'Myriel', 'MmeDeR', 'Toussaint', 'Claquesous', 'Champmathieu', 'Woman1', 'Enjolras', 'Fauchelevent', 'Gervais', 'Judge', 'Labarre', 'Isabeau', 'Woman2', 'Cochepaille', 'MlleGillenormand', 'Marguerite', 'Babet', 'Bamatabois', 'Chenildieu', 'Simplice', 'MmeThenardier', 'MotherInnocent', 'MmeMagloire', 'Scaufflaire', 'Thenardier', 'Marius', 'Bossuet', 'Gavroche', 'Fantine'}
# Gavroche
# {'MmeHucheloup', 'Javert', 'Brujon', 'Prouvaire', 'Gueulemer', 'Valjean', 'Montparnasse', 'Child1', 'Feuilly', 'Grantaire', 'MmeBurgon', 'Enjolras', 'Mabeuf', 'Joly', 'Bahorel', 'Babet', 'Courfeyrac', 'Thenardier', 'Marius', 'Bossuet', 'Child2', 'Combeferre'}
# Marius
# {'Gillenormand', 'Valjean', 'Feuilly', 'Cosette', 'LtGillenormand', 'Eponine', 'Enjolras', 'BaronessT', 'Mabeuf', 'Joly', 'Pontmercy', 'MlleGillenormand', 'Bahorel', 'Courfeyrac', 'Thenardier', 'Tholomyes', 'Bossuet', 'Gavroche', 'Combeferre'}

# %%
# Top 5 pairs in terms of structural similarity are: 
# By using Jaccard coefficient, we get:
sorted(list(nx.jaccard_coefficient(fil)),key=lambda x: x[2],reverse = True)[0:5]
# Out:
# [('OldMan', 'Champtercier', 1.0),
#  ('OldMan', 'CountessDeLo', 1.0),
#  ('OldMan', 'Cravatte', 1.0),
#  ('OldMan', 'Count', 1.0),
#  ('OldMan', 'Geborand', 1.0)]

# %%
#By using pearson correlation coefficient
x = list(fil.nodes())
no = []
pe = []
for i in range(len(x)):
    for j in range(len(x)):
        node = (x[i] , x[j])
        no.append(node)
        pe.append(nx.degree_pearson_correlation_coefficient(fil,node))

dictionary = dict(zip(no,pe))

m = sorted(dictionary,key=lambda x: x[1],reverse = True)
print(m[0:5])
# Out:
# [('Myriel', 'Zephine'), ('Napoleon', 'Zephine'), ('MlleBaptistine', 'Zephine'), ('MmeMagloire', 'Zephine'), ('CountessDeLo', 'Zephine')]

# %% [markdown]
# ### Clustering coefficients of each node and the global clustering coefficient

# %%
print("The local clustering coefficients are: ")
nx.clustering(fil)
# Out:
# The local clustering coefficients are:
# {'Myriel': 0.06666666666666667,
#  'Napoleon': 0,
#  'MlleBaptistine': 1.0,
#  'MmeMagloire': 1.0,
#  'CountessDeLo': 0,
#  'Geborand': 0,
#  'Champtercier': 0,
#  'Cravatte': 0,
#  'Count': 0,
#  'OldMan': 0,
#  'Labarre': 0,
#  'Valjean': 0.12063492063492064,
#  'Marguerite': 1.0,
#  'MmeDeR': 0,
#  'Isabeau': 0,
#  'Gervais': 0,
#  'Tholomyes': 0.6111111111111112,
#  'Listolier': 1.0,
#  'Fameuil': 1.0,
#  'Blacheville': 1.0,
#  'Favourite': 1.0,
#  'Dahlia': 1.0,
#  'Zephine': 1.0,
#  'Fantine': 0.3142857142857143,
#  'MmeThenardier': 0.4909090909090909,
#  'Thenardier': 0.4083333333333333,
#  'Cosette': 0.38181818181818183,
#  'Javert': 0.3235294117647059,
#  'Fauchelevent': 0.3333333333333333,
#  'Bamatabois': 0.6428571428571429,
#  'Perpetue': 1.0,
#  'Simplice': 0.6666666666666666,
#  'Scaufflaire': 0,
#  'Woman1': 1.0,
#  'Judge': 1.0,
#  'Champmathieu': 1.0,
#  'Brevet': 1.0,
#  'Chenildieu': 1.0,
#  'Cochepaille': 1.0,
#  'Pontmercy': 0.3333333333333333,
#  'Boulatruelle': 0,
#  'Eponine': 0.45454545454545453,
#  'Anzelma': 1.0,
#  'Woman2': 1.0,
#  'MotherInnocent': 1.0,
#  'Gribier': 0,
#  'Jondrette': 0,
#  'MmeBurgon': 0,
#  'Gavroche': 0.354978354978355,
#  'Gillenormand': 0.47619047619047616,
#  'Magnon': 0,
#  'MlleGillenormand': 0.42857142857142855,
#  'MmePontmercy': 0,
#  'MlleVaubois': 0,
#  'LtGillenormand': 1.0,
#  'Marius': 0.3333333333333333,
#  'BaronessT': 1.0,
#  'Mabeuf': 0.6909090909090909,
#  'Enjolras': 0.6095238095238096,
#  'Combeferre': 0.9272727272727272,
#  'Prouvaire': 1.0,
#  'Feuilly': 0.9272727272727272,
#  'Courfeyrac': 0.7564102564102564,
#  'Bahorel': 0.8636363636363636,
#  'Bossuet': 0.7692307692307693,
#  'Joly': 0.8636363636363636,
#  'Grantaire': 0.9333333333333333,
#  'MotherPlutarch': 0,
#  'Gueulemer': 0.8,
#  'Babet': 0.8,
#  'Claquesous': 0.7111111111111111,
#  'Montparnasse': 0.8333333333333334,
#  'Toussaint': 1.0,
#  'Child1': 1.0,
#  'Child2': 1.0,
#  'Brujon': 0.9047619047619048,
#  'MmeHucheloup': 1.0}

# %%
print("The global clustering coefficient is: ",nx.average_clustering(fil))
# Out:
# The global clustering coefficient is:  0.5731367499320134

# %% [markdown]
# ### Detecting sub-structures ( k clique, K core etc)

# %%
# Connected components
print("The connected components are:",list(nx.connected_components(fil)))
print()
print("The biconnectes components are:",list(nx.biconnected_components(fil)))
print()
print("The k-components of graph are: ",nx.k_components(fil))
# Out:
# The connected components are: [{'Gillenormand', 'Javert', 'Valjean', 'Feuilly', 'Boulatruelle', 'Eponine', 'MmeBurgon', 'Listolier', 'Enjolras', 'OldMan', 'Jondrette', 'Labarre', 'Zephine', 'Champtercier', 'Babet', 'CountessDeLo', 'MlleBaptistine', 'MmeHucheloup', 'Gueulemer', 'Child1', 'Favourite', 'LtGillenormand', 'Anzelma', 'Cravatte', 'Champmathieu', 'Woman2', 'Isabeau', 'Dahlia', 'Count', 'Chenildieu', 'MmeThenardier', 'Scaufflaire', 'Thenardier', 'Marius', 'Magnon', 'MotherPlutarch', 'Child2', 'Blacheville', 'Brujon', 'MlleVaubois', 'Montparnasse', 'MmePontmercy', 'Perpetue', 'MmeDeR', 'Grantaire', 'Toussaint', 'Gervais', 'Judge', 'BaronessT', 'Cochepaille', 'MlleGillenormand', 'Marguerite', 'Simplice', 'Gribier', 'Courfeyrac', 'MotherInnocent', 'Tholomyes', 'Bossuet', 'Gavroche', 'Combeferre', 'Prouvaire', 'Brevet', 'Cosette', 'Myriel', 'Claquesous', 'Woman1', 'Fauchelevent', 'Mabeuf', 'Joly', 'Pontmercy', 'Bahorel', 'Bamatabois', 'Geborand', 'Fameuil', 'MmeMagloire', 'Napoleon', 'Fantine'}]
#
# The biconnectes components are: [{'Napoleon', 'Myriel'}, {'Labarre', 'Valjean'}, {'Gribier', 'Fauchelevent'}, {'Jondrette', 'MmeBurgon'}, {'Gavroche', 'MmeBurgon'}, {'MlleGillenormand', 'MlleVaubois'}, {'Mabeuf', 'MotherPlutarch'}, {'Gavroche', 'Child2', 'Child1'}, {'Boulatruelle', 'Thenardier'}, {'Blacheville', 'MmeHucheloup', 'Gillenormand', 'Javert', 'Brujon', 'Prouvaire', 'Brevet', 'Gueulemer', 'Valjean', 'MmePontmercy', 'Montparnasse', 'Feuilly', 'Cosette', 'Perpetue', 'Grantaire', 'Toussaint', 'Favourite', 'LtGillenormand', 'Eponine', 'Anzelma', 'Claquesous', 'Listolier', 'Champmathieu', 'Woman1', 'Enjolras', 'Fauchelevent', 'Judge', 'Woman2', 'Zephine', 'BaronessT', 'Cochepaille', 'Mabeuf', 'Joly', 'Pontmercy', 'Dahlia', 'MlleGillenormand', 'Marguerite', 'Bahorel', 'Babet', 'Bamatabois', 'Chenildieu', 'Simplice', 'MmeThenardier', 'Fameuil', 'Courfeyrac', 'MotherInnocent', 'Thenardier', 'Tholomyes', 'Marius', 'Magnon', 'Bossuet', 'Gavroche', 'Fantine', 'Combeferre'}, {'Valjean', 'MmeDeR'}, {'Valjean', 'Isabeau'}, {'Gervais', 'Valjean'}, {'Scaufflaire', 'Valjean'}, {'MlleBaptistine', 'Valjean', 'MmeMagloire', 'Myriel'}, {'CountessDeLo', 'Myriel'}, {'Geborand', 'Myriel'}, {'Myriel', 'Champtercier'}, {'Cravatte', 'Myriel'}, {'Count', 'Myriel'}, {'OldMan', 'Myriel'}]
#
# The k-components of graph are:  {9: [{'Grantaire', 'Courfeyrac', 'Joly', 'Bahorel', 'Prouvaire', 'Enjolras', 'Bossuet', 'Feuilly', 'Gavroche', 'Combeferre'}, {'Courfeyrac', 'Mabeuf', 'Joly', 'Bahorel', 'Marius', 'Enjolras', 'Bossuet', 'Feuilly', 'Gavroche', 'Combeferre'}], 8: [{'Grantaire', 'Courfeyrac', 'Mabeuf', 'Joly', 'Bahorel', 'Prouvaire', 'Marius', 'Enjolras', 'Bossuet', 'Feuilly', 'Gavroche', 'Combeferre'}], 7: [{'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine'}, {'Grantaire', 'Courfeyrac', 'Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Marius', 'Enjolras', 'Bossuet', 'Feuilly', 'Gavroche', 'Combeferre'}, {'Javert', 'Brujon', 'Eponine', 'Babet', 'Thenardier', 'Claquesous', 'Gueulemer', 'Montparnasse', 'Valjean', 'Gavroche', 'MmeThenardier'}], 6: [{'Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge'}, {'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine'}, {'Grantaire', 'Courfeyrac', 'Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Marius', 'Enjolras', 'Bossuet', 'Feuilly', 'Gavroche', 'Combeferre'}, {'Javert', 'Brujon', 'Eponine', 'Babet', 'Thenardier', 'Claquesous', 'Gueulemer', 'Montparnasse', 'Valjean', 'Gavroche', 'MmeThenardier'}], 5: [{'Mabeuf', 'MmeHucheloup', 'Joly', 'Javert', 'Brujon', 'Bahorel', 'Babet', 'Prouvaire', 'Gueulemer', 'Montparnasse', 'Valjean', 'Feuilly', 'MmeThenardier', 'Grantaire', 'Courfeyrac', 'Eponine', 'Thenardier', 'Claquesous', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre'}, {'Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge'}, {'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine'}], 4: [{'Marius', 'LtGillenormand', 'Valjean', 'Gillenormand', 'MlleGillenormand', 'Cosette'}, {'Mabeuf', 'MmeHucheloup', 'Joly', 'Javert', 'Brujon', 'Bahorel', 'Babet', 'Prouvaire', 'Gueulemer', 'Montparnasse', 'Valjean', 'Feuilly', 'MmeThenardier', 'Grantaire', 'Courfeyrac', 'Eponine', 'Thenardier', 'Claquesous', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre'}, {'Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge'}, {'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine'}], 3: [{'MmeHucheloup', 'Gillenormand', 'Javert', 'Brujon', 'Prouvaire', 'Gueulemer', 'Valjean', 'Montparnasse', 'Feuilly', 'Cosette', 'Grantaire', 'Toussaint', 'LtGillenormand', 'Eponine', 'Anzelma', 'Claquesous', 'Enjolras', 'Woman2', 'Mabeuf', 'Joly', 'MlleGillenormand', 'Bahorel', 'Babet', 'MmeThenardier', 'Courfeyrac', 'Thenardier', 'Tholomyes', 'Marius', 'Bossuet', 'Gavroche', 'Fantine', 'Combeferre'}, {'MlleBaptistine', 'Valjean', 'MmeMagloire', 'Myriel'}, {'Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge'}, {'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine'}], 2: [{'Gavroche', 'Child2', 'Child1'}, {'Blacheville', 'MmeHucheloup', 'Gillenormand', 'Javert', 'Brujon', 'Prouvaire', 'Brevet', 'Gueulemer', 'Valjean', 'MmePontmercy', 'Montparnasse', 'Feuilly', 'Cosette', 'Perpetue', 'Grantaire', 'Toussaint', 'Favourite', 'LtGillenormand', 'Eponine', 'Anzelma', 'Claquesous', 'Listolier', 'Champmathieu', 'Woman1', 'Enjolras', 'Fauchelevent', 'Judge', 'Woman2', 'Zephine', 'BaronessT', 'Cochepaille', 'Mabeuf', 'Joly', 'Pontmercy', 'Dahlia', 'MlleGillenormand', 'Marguerite', 'Bahorel', 'Babet', 'Bamatabois', 'Chenildieu', 'Simplice', 'MmeThenardier', 'Fameuil', 'Courfeyrac', 'MotherInnocent', 'Thenardier', 'Tholomyes', 'Marius', 'Magnon', 'Bossuet', 'Gavroche', 'Fantine', 'Combeferre'}, {'MlleBaptistine', 'Valjean', 'MmeMagloire', 'Myriel'}], 1: [{'Blacheville', 'Gillenormand', 'Javert', 'Brujon', 'MlleVaubois', 'Valjean', 'Montparnasse', 'MmePontmercy', 'Feuilly', 'Boulatruelle', 'Perpetue', 'MmeDeR', 'Grantaire', 'Toussaint', 'Eponine', 'MmeBu ...

# %%
# K-clique for k = 5
clique = list(nx.algorithms.community.k_clique_communities(fil,5))
for i in clique:
    print(list(i))
# Out:
# ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
# ['Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Valjean', 'Feuilly', 'Grantaire', 'Courfeyrac', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre']
# ['Javert', 'Brujon', 'Babet', 'Gueulemer', 'Montparnasse', 'Valjean', 'Cosette', 'MmeThenardier', 'Eponine', 'Thenardier', 'Claquesous', 'Gavroche', 'Fantine']
# ['LtGillenormand', 'Gillenormand', 'MlleGillenormand', 'Marius', 'Valjean', 'Cosette']
# ['Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge']

# %%
#K-core when k is the largest degree
core = nx.k_core(fil)
nx.draw_networkx(core)
plt.show()

# %% [markdown]
# ### Detecting communities using Louvain method

# %%
#Louvain method
import community
from community import community_louvain
G = fil
# print(community_louvain.best_partition(G))
part = community_louvain.best_partition(G)
mod = community_louvain.modularity(part,G)

#plot, color nodes using community structure
values = [part.get(node) for node in G.nodes()]
# print(part)
print('The nodes having the same colors belong to one community')
nx.draw_spring(G, cmap = plt.get_cmap('jet'), node_color = values, node_size=30, with_labels=False)
plt.show()


#print the list of communities
size = float(len(set(part.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(part.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in part.keys()
                                if part[nodes] == com]
    print("Community ",int(count),": ",list_nodes)
# Out:
# The nodes having the same colors belong to one community
# Community  1 :  ['Jondrette', 'MmeBurgon']
# Community  2 :  ['Myriel', 'Napoleon', 'MlleBaptistine', 'MmeMagloire', 'CountessDeLo', 'Geborand', 'Champtercier', 'Cravatte', 'Count', 'OldMan']
# Community  3 :  ['Labarre', 'Valjean', 'MmeDeR', 'Isabeau', 'Gervais', 'Fauchelevent', 'Bamatabois', 'Scaufflaire', 'Woman1', 'Judge', 'Champmathieu', 'Brevet', 'Chenildieu', 'Cochepaille', 'MotherInnocent', 'Gribier']
# Community  4 :  ['Marguerite', 'Tholomyes', 'Listolier', 'Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Zephine', 'Fantine', 'Perpetue', 'Simplice']
# Community  5 :  ['MmeThenardier', 'Thenardier', 'Javert', 'Boulatruelle', 'Eponine', 'Anzelma', 'Gueulemer', 'Babet', 'Claquesous', 'Montparnasse', 'Brujon']
# Community  6 :  ['Gavroche', 'Marius', 'Mabeuf', 'Enjolras', 'Combeferre', 'Prouvaire', 'Feuilly', 'Courfeyrac', 'Bahorel', 'Bossuet', 'Joly', 'Grantaire', 'MotherPlutarch', 'Child1', 'Child2', 'MmeHucheloup']
# Community  7 :  ['Cosette', 'Pontmercy', 'Woman2', 'Gillenormand', 'Magnon', 'MlleGillenormand', 'MmePontmercy', 'MlleVaubois', 'LtGillenormand', 'BaronessT', 'Toussaint']

# %% [markdown]
# ### Detecting communities using Clique percolation method

# %%
# Clique percolation method

from networkx.algorithms.community import k_clique_communities

# Let us consider communities with K = 3

cpm = list(k_clique_communities(G,3))

for i in cpm:
    print('community with K=3: ',list(i))
    print()
    

print("------------------------------------------------------------------------------------------------------")
# Let us consider communities with K = 4

cpm = list(k_clique_communities(G,4))

for i in cpm:
    print('community with K=4: ',list(i))
    print()
    

print("------------------------------------------------------------------------------------------------------")
# Let us consider communities with K = 5

cpm = list(k_clique_communities(G,5))

for i in cpm:
    print('community with K=5: ',list(i))
    print()
    

print("------------------------------------------------------------------------------------------------------")
# Let us consider communities with K = 6

cpm = list(k_clique_communities(G,6))

for i in cpm:
    print('community with K=6: ',list(i))
    print()
    

print("------------------------------------------------------------------------------------------------------")
# Let us consider communities with K = 8

cpm = list(k_clique_communities(G,8))

for i in cpm:
    print('community with K=8: ',list(i))
    print()
# Out:
# community with K=3:  ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
#
# community with K=3:  ['MmeHucheloup', 'Gillenormand', 'Javert', 'Brujon', 'Prouvaire', 'Brevet', 'Gueulemer', 'Valjean', 'Montparnasse', 'Feuilly', 'Cosette', 'Perpetue', 'Grantaire', 'Toussaint', 'LtGillenormand', 'Eponine', 'Anzelma', 'Claquesous', 'Champmathieu', 'Enjolras', 'Woman1', 'Fauchelevent', 'Judge', 'Woman2', 'BaronessT', 'Cochepaille', 'Mabeuf', 'Joly', 'Pontmercy', 'MlleGillenormand', 'Marguerite', 'Bahorel', 'Babet', 'Bamatabois', 'Chenildieu', 'Simplice', 'MmeThenardier', 'Courfeyrac', 'MotherInnocent', 'Thenardier', 'Tholomyes', 'Marius', 'Bossuet', 'Gavroche', 'Fantine', 'Combeferre']
#
# community with K=3:  ['MlleBaptistine', 'MmeMagloire', 'Valjean', 'Myriel']
#
# community with K=3:  ['Gavroche', 'Child2', 'Child1']
#
# ------------------------------------------------------------------------------------------------------
# community with K=4:  ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
#
# community with K=4:  ['MmeHucheloup', 'Gillenormand', 'Javert', 'Brujon', 'Prouvaire', 'Gueulemer', 'Montparnasse', 'Valjean', 'Feuilly', 'Cosette', 'Grantaire', 'Toussaint', 'LtGillenormand', 'Eponine', 'Anzelma', 'Claquesous', 'Enjolras', 'Woman2', 'Mabeuf', 'Joly', 'MlleGillenormand', 'Bahorel', 'Babet', 'Bamatabois', 'Simplice', 'MmeThenardier', 'Courfeyrac', 'Thenardier', 'Marius', 'Bossuet', 'Gavroche', 'Fantine', 'Combeferre']
#
# community with K=4:  ['MlleBaptistine', 'MmeMagloire', 'Valjean', 'Myriel']
#
# community with K=4:  ['Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge']
#
# ------------------------------------------------------------------------------------------------------
# community with K=5:  ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
#
# community with K=5:  ['Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Valjean', 'Feuilly', 'Grantaire', 'Courfeyrac', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre']
#
# community with K=5:  ['Javert', 'Brujon', 'Babet', 'Gueulemer', 'Montparnasse', 'Valjean', 'Cosette', 'MmeThenardier', 'Eponine', 'Thenardier', 'Claquesous', 'Gavroche', 'Fantine']
#
# community with K=5:  ['LtGillenormand', 'Gillenormand', 'MlleGillenormand', 'Marius', 'Valjean', 'Cosette']
#
# community with K=5:  ['Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge']
#
# ------------------------------------------------------------------------------------------------------
# community with K=6:  ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
#
# community with K=6:  ['Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Feuilly', 'Grantaire', 'Courfeyrac', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre']
#
# community with K=6:  ['Eponine', 'Brujon', 'Javert', 'Babet', 'Thenardier', 'Claquesous', 'Gueulemer', 'Montparnasse', 'Valjean', 'Gavroche', 'MmeThenardier']
#
# community with K=6:  ['Brevet', 'Bamatabois', 'Cochepaille', 'Champmathieu', 'Valjean', 'Chenildieu', 'Judge']
#
# ------------------------------------------------------------------------------------------------------
# community with K=8:  ['Fameuil', 'Blacheville', 'Favourite', 'Dahlia', 'Listolier', 'Tholomyes', 'Fantine', 'Zephine']
#
# community with K=8:  ['Mabeuf', 'Joly', 'MmeHucheloup', 'Bahorel', 'Prouvaire', 'Feuilly', 'Grantaire', 'Courfeyrac', 'Marius', 'Enjolras', 'Bossuet', 'Gavroche', 'Combeferre']

# %%
# Another method to find the communities using clique percolation method:
list(nx.find_cliques(G))
synthetic = nx.make_max_clique_graph(G)
# Finds the maximal cliques and treats these as nodes.
# The nodes are connected if they have common members in the original graph.
print(synthetic.edges())

nx.draw_networkx(synthetic,node_color='red')
plt.show()
# Out:
# [(0, 9), (0, 14), (0, 19), (0, 26), (0, 37), (0, 56), (1, 3), (1, 4), (1, 11), (1, 16), (1, 17), (1, 29), (1, 30), (1, 32), (1, 35), (1, 39), (1, 43), (2, 3), (2, 9), (2, 10), (2, 11), (2, 12), (2, 13), (2, 17), (2, 30), (2, 31), (2, 36), (2, 39), (2, 40), (2, 41), (2, 42), (2, 50), (3, 4), (3, 9), (3, 10), (3, 11), (3, 12), (3, 13), (3, 16), (3, 29), (3, 30), (3, 31), (3, 32), (3, 35), (3, 36), (3, 40), (3, 41), (3, 42), (3, 43), (3, 50), (4, 11), (4, 16), (4, 17), (4, 29), (4, 30), (4, 32), (4, 35), (4, 39), (4, 43), (5, 7), (5, 33), (5, 38), (6, 7), (6, 8), (6, 9), (6, 10), (6, 11), (6, 12), (6, 13), (6, 14), (6, 15), (6, 16), (6, 17), (6, 18), (6, 19), (6, 20), (6, 21), (6, 22), (6, 23), (6, 24), (6, 25), (6, 26), (6, 27), (6, 28), (6, 29), (6, 30), (6, 31), (6, 45), (6, 46), (6, 47), (6, 51), (6, 52), (6, 54), (6, 55), (7, 8), (7, 9), (7, 10), (7, 11), (7, 12), (7, 13), (7, 14), (7, 15), (7, 16), (7, 17), (7, 18), (7, 19), (7, 20), (7, 21), (7, 22), (7, 23), (7, 24), (7, 25), (7, 26), (7, 27), (7, 28), (7, 29), (7, 30), (7, 31), (7, 33), (7, 35), (7, 38), (7, 39), (7, 40), (7, 48), (7, 50), (7, 56), (7, 57), (8, 9), (8, 10), (8, 11), (8, 12), (8, 13), (8, 14), (8, 15), (8, 16), (8, 17), (8, 18), (8, 19), (8, 20), (8, 21), (8, 22), (8, 23), (8, 24), (8, 25), (8, 26), (8, 27), (8, 28), (8, 29), (8, 30), (8, 31), (8, 38), (8, 56), (9, 10), (9, 11), (9, 12), (9, 13), (9, 14), (9, 15), (9, 16), (9, 17), (9, 18), (9, 19), (9, 20), (9, 21), (9, 22), (9, 23), (9, 24), (9, 25), (9, 26), (9, 27), (9, 28), (9, 29), (9, 30), (9, 31), (9, 36), (9, 37), (9, 40), (9, 41), (9, 42), (9, 50), (9, 58), (10, 11), (10, 12), (10, 13), (10, 14), (10, 15), (10, 16), (10, 17), (10, 18), (10, 19), (10, 20), (10, 21), (10, 22), (10, 23), (10, 24), (10, 25), (10, 26), (10, 27), (10, 28), (10, 29), (10, 30), (10, 31), (10, 36), (10, 38), (10, 40), (10, 41), (10, 42), (10, 50), (10, 56), (10, 58), (11, 12), (11, 13), (11, 14), (11, 15), (11, 16), (11, 17), (11, 18), (11, 19), (11, 20), (11, 21), (11, 22), (11, 23), (11, 24), (11, 25), (11, 26), (11, 27), (11, 28), (11, 29), (11, 30), (11, 31), (11, 32), (11, 35), (11, 36), (11, 40), (11, 41), (11, 42), (11, 43), (11, 50), (12, 13), (12, 14), (12, 15), (12, 16), (12, 17), (12, 18), (12, 19), (12, 20), (12, 21), (12, 22), (12, 23), (12, 24), (12, 25), (12, 26), (12, 27), (12, 28), (12, 29), (12, 30), (12, 31), (12, 36), (12, 40), (12, 41), (12, 42), (12, 50), (13, 14), (13, 15), (13, 16), (13, 17), (13, 18), (13, 19), (13, 20), (13, 21), (13, 22), (13, 23), (13, 24), (13, 25), (13, 26), (13, 27), (13, 28), (13, 29), (13, 30), (13, 31), (13, 36), (13, 40), (13, 41), (13, 42), (13, 50), (13, 58), (14, 15), (14, 16), (14, 17), (14, 18), (14, 19), (14, 20), (14, 21), (14, 22), (14, 23), (14, 24), (14, 25), (14, 26), (14, 27), (14, 28), (14, 29), (14, 30), (14, 31), (14, 37), (15, 16), (15, 17), (15, 18), (15, 19), (15, 20), (15, 21), (15, 22), (15, 23), (15, 24), (15, 25), (15, 26), (15, 27), (15, 28), (15, 29), (15, 30), (15, 31), (16, 17), (16, 18), (16, 19), (16, 20), (16, 21), (16, 22), (16, 23), (16, 24), (16, 25), (16, 26), (16, 27), (16, 28), (16, 29), (16, 30), (16, 31), (16, 32), (16, 35), (16, 43), (17, 18), (17, 19), (17, 20), (17, 21), (17, 22), (17, 23), (17, 24), (17, 25), (17, 26), (17, 27), (17, 28), (17, 29), (17, 30), (17, 31), (17, 35), (17, 42), (18, 19), (18, 20), (18, 21), (18, 22), (18, 23), (18, 24), (18, 25), (18, 26), (18, 27), (18, 28), (18, 29), (18, 30), (18, 31), (18, 53), (19, 20), (19, 21), (19, 22), (19, 23), (19, 24), (19, 25), (19, 26), (19, 27), (19, 28), (19, 29), (19, 30), (19, 31), (19, 37), (20, 21), (20, 22), (20, 23), (20, 24), (20, 25), (20, 26), (20, 27), (20, 28), (20, 29), (20, 30), (20, 31), (20, 38), (20, 56), (21, 22), (21, 23), (21, 24), (21, 25), (21, 26), (21, 27), (21, 28), (21, 29), (21, 30), (21, 31), (22, 23), (22, 24), (22, 25), (22, 26), (22, 27), (22, 28), (22, 29), (22, 30), (22, 31), (23, 24), (23, 25), (23, 26), (23, 27), (23, 28), (23, 29), (23, ...

# %% [markdown]
# ### Comparing centrality measures

# %%
import pandas as pd
import seaborn as sns
sns.set(style="ticks", color_codes=True)

degc = nx.degree_centrality(G)
bet = nx.betweenness_centrality(G)
clos = nx.closeness_centrality(G)
eig = nx.eigenvector_centrality(G)

centrality_measures = {
'degree': degc,
'betweenness': bet,
'closeness': clos,
'eigenvector': eig,
}
centrality = pd.DataFrame(centrality_measures)
centrality
sns.pairplot(centrality)
plt.show()

# %% [markdown]
# # Final Analysis
#
# ### Graph Overview:
# The graph has 77 nodes indicating 77 characters in the novel.
# There are 254 edges indicting that there are 254 relationships between people.
#
# Even though the graph has smaller clusters, on a whole it is a single component. So, every character in the novel is somehow connected to the other. The relationship might be weak or strong depending on the weights of the edges and the distance between two nodes.
#
# ### Centrality Analysis:
# The top 5 degrees of centrality are as follows:
#
#     eigen vector centrality:
#                 ('Gavroche', 0.31783893977497674)
#                 ('Valjean', 0.2676181759885393)
#                 ('Enjolras', 0.26717863282356663)
#                 ('Marius', 0.25911114534178753)
#                 ('Bossuet', 0.24213078637474134)
#
#     degree centrality:
#                 ('Valjean', 0.47368421052631576)
#                 ('Gavroche', 0.2894736842105263)
#                 ('Marius', 0.25)
#                 ('Javert', 0.22368421052631576)
#                 ('Thenardier', 0.21052631578947367)
#
#     closeness centrality:
#                 ('Valjean', 0.6440677966101694)
#                 ('Marius', 0.5314685314685315)
#                 ('Thenardier', 0.5170068027210885)
#                 ('Javert', 0.5170068027210885)
#                 ('Gavroche', 0.5135135135135135)
#
#     betweenness centrality:
#                 ('Valjean', 0.5699890527836184)
#                 ('Myriel', 0.17684210526315788)
#                 ('Gavroche', 0.16511250242584766)
#                 ('Marius', 0.132032488621946)
#                 ('Fantine', 0.12964454098819422)
#
#
# By looking at the centrality values, we can easily say that 'Valjean' is the protagonist of the novel without even seeing the cover face of the book.
# Valjean is related to 47% of the characters (about 36 out of 77) directly. The next best being 28% (about 21 out of 77). This clearly imdicates that he is the most popular character of the novel.
#
# The most popular person may not be the most important person. This is the difference between degree centrality and betweenness centrality.
#
# We consider the node with highest betweenness centrality to be the most important node of a social network graph because it is like a bridge which connects two entirely different components of the graph. That one character can change a lot in the plot. So, in this novel, the highest degree centrality is for 'Valjean' only. So we can conclude that he is the most important of all.
#
# One more interesting point that we can take a look at is that, Myriel has the second highest betweennes centrality but his degree centrality is very high. So we can say that he is an introvert wo doesn't have many relationships but he is very important for the plot of the novel. So he has acted as a bridge between many characters and has been helpful to his acquaintances.
#
# There is one measure in this graph where we see a differnt result. 'Jean Valjean' is not the one whi has the higest measure in this. For eigen vector centrality, the highest value is attained by 'Gavroche'. So, we can say that he is the most influential person in the plot of the novel.
#
# Coming to the correlation plot,
#     i) We can see that most of the values of betweenness centrality are near to 0. So it is very less. This shows that there are        very few important people and can also mean that the no. of unconnected components is very less because the edges that          work as bridges are less in this case.
#     ii) We can see that closeness centrality is spread out like a normal distribution. This says that the central nodes are of
#         average number.
#     iii) We can see that both degree cetrality and eigen-vector centrality have more values near 0 and decrease further. So we can say that there are not so many characters which are popular.
#     iv) Betweenness centrality is positively correlated to all other centralities but the correlation is very low. So it means that important charcaters may not be popular or central or inluential.
#     v) All other centralities are positively correlated to all other centralities because usually popular,influential and central go hand in had with each other. centralities. A central node can be popular, central and influential.
#
# ### Community Detection:
#
# Some of the communities detected here are:
#
#             community with K=3:  ['Tholomyes', 'Zephine', 'Listolier', 'Favourite', 'Blacheville', 'Fantine', 'Fameuil', 'Dahlia']
#
#             community with K=3:  ['MotherInnocent', 'MmeThenardier', 'Cochepaille', 'Fantine', 'MlleGillenormand', 'Joly', 'Gueulemer', 'Marius', 'BaronessT', 'Bossuet', 'Javert', 'Brujon', 'MmeHucheloup', 'Enjolras', 'Bamatabois', 'Brevet', 'Toussaint', 'LtGillenormand', 'Grantaire', 'Simplice', 'Gavroche', 'Courfeyrac', 'Montparnasse', 'Pontmercy', 'Mabeuf', 'Claquesous', 'Tholomyes', 'Champmathieu', 'Woman2', 'Bahorel', 'Fauchelevent', 'Perpetue', 'Thenardier', 'Valjean', 'Babet', 'Anzelma', 'Chenildieu', 'Gillenormand', 'Eponine', 'Judge', 'Prouvaire', 'Feuilly', 'Combeferre', 'Cosette', 'Woman1', 'Marguerite']
#
#             community with K=3:  ['MlleBaptistine', 'Myriel', 'MmeMagloire', 'Valjean']
#
#             community with K=3:  ['Child1', 'Child2', 'Gavroche']
#
#             community with K=4:  ['Tholomyes', 'Zephine', 'Listolier', 'Favourite', 'Blacheville', 'Fantine', 'Fameuil', 'Dahlia']
#
#             community with K=4:  ['Gavroche', 'MmeThenardier', 'Courfeyrac', 'Montparnasse', 'Mabeuf', 'Claquesous', 'Woman2', 'Bahorel', 'Thenardier', 'Valjean', 'Babet', 'Fantine', 'MlleGillenormand', 'Anzelma', 'Joly', 'Gueulemer', 'Marius', 'Javert', 'Brujon', 'MmeHucheloup', 'Eponine', 'Gillenormand', 'Prouvaire', 'Enjolras', 'Bamatabois', 'Feuilly', 'Combeferre', 'Toussaint', 'LtGillenormand', 'Cosette', 'Grantaire', 'Simplice', 'Bossuet']
#
#             community with K=4:  ['MlleBaptistine', 'Myriel', 'MmeMagloire', 'Valjean']
#
#             community with K=4:  ['Judge', 'Bamatabois', 'Valjean', 'Brevet', 'Cochepaille', 'Champmathieu', 'Chenildieu']
#
# We can see that the characters that occur in the same frame, or closeby in the novel are grouped into the same communities. For example, Jean Valjean was seen with Myriel most of the time. So, irrespective of K value, always these both are in the same component.
#
# ### Analysis on the structural similarity:
#
# The structural similarity is 1 for a lot of nodes whose degree is also 1. This is not a very good measure atleast when the degree is low because everyone who is connected to valjean alone will have the same structural similarity.
# And with Jaccard similarity, as it is the length(intersection) by length(union). So if the similarity is 1, then it means that the intersection and union are of the same length. So it basically leads to both the nodes having almost the same degree centrality if the Jaccard coefficient is 1.
#
#
# ### Analysing the clusters, density and diameter:
#
# The global clustering coefficient is based on the number of connected triplets. It gives an indication of the clustering in the whole network on a whole. The value we have got is 0.5731367499320134. This means that around 57% of the total number of triplets are closed triplets.
#
# The diameter (longest path between any two characters) is 5.
# This means that from any one character the maximum that any other character would be away from that character would be through 5 other characters. The average distance between any two characters is 2.6. This shows that each distinct character is generally 2 to 3 characters away from any other character.
#
# The network density of the graph is around 8.6% only. This shows that the graph is actually very sparse. 8% of 77-C-2 is around 77 out of the 2926 distinct edges possible.
#
#
# ### Other interesting observations:
#
# The novel is a single component. This means everyone in the novel knows everyone else atleast indirectly. One of the most interesting observation is Gavroche's eigen-vector centrality. This character is the most influential character because it has the most influencing connections in the novel. But his degree centrality is still low, that is he does not have the most connections. Jean
# Valjean's clustering coefficient is comparatively, and it means that many of his acquaintances don’t know one another. And several other characters also have very high clustering coefficients, so their networks are comparatively smaller and denser than Valjean’s. Valjean beats everyone by a very high margin in betweenness centrality and the degree centrality. This is where he scores more than the rest and is concluded as the protagonist.
